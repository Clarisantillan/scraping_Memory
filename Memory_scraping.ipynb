# %%
# !pip install selenium
# !pip install Pillow
# Out:
# Collecting selenium
#   Downloading selenium-4.19.0-py3-none-any.whl (10.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 41.6 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.25.0-py3-none-any.whl (467 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 28.2 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.10.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.6)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.19.0 trio-0.25.0 trio-websocket-0.11.1 wsproto-1.2.0
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
import requests

# solicitud HTTP a la página
url = "https://www.memorykings.pe/listados/1028/laptops-intel-celeron-empresarial"
response = requests.get(url)

# fue exitosa?
if response.status_code == 200:
    # Obtener el HTML de la página
    html_content = response.text
    print(html_content)
else:
    print("Error al cargar la página:", response.status_code)
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#
# 	<title>Laptops | Intel Celeron Empresarial - Memory Kings, lo mejor en equipos de computo y accesorios</title>
#
# 	<!-- Google / Inicio -->
# 	<meta name="google-site-verification" content="4x46USn6qIYx_GdXAEAxu-jg9Xyh9wfQzGVQCMo-9d4" />
# 	<meta name="description" content="Memory Kings Perú lo mejor en equipos de computo y accesorios, solo las mejores marcas">
# 	<meta name="keywords" content="Memory Kings, equipos de computo, accesorios de computo, mejores marcas" />
# 	<meta name="news_keywords" content="Memory Kings, equipos de computo, accesorios de computo, mejores marcas"/>
# 	<meta name="language" content="es" />
# 	<meta name="robots" content="index,follow"/>
# 	<meta name="googlebot" content="index, follow" />
# 	<meta name="organization" content="Memory Kings Perú SAC" />
# 	<meta name="revisit-after" content="1 day" />
# 	<meta name="author" content="Memory Kings Perú">
# 	<meta name="copyright" content="© 2013 www.memorykings.com.pe" />
# 	<meta name="origen" content="Memory Kings Perú" />
# 	<meta name="locality" content="Lima, Peru" />
# 	<meta name="distribution" content="global" />
# 	<link rel="image_src" href="" />
# 	<link rel="canonical" href="https://www.memorykings.pe/listados/1028/laptops-intel-celeron-empresarial"/>
# 	<!-- Google / Fin -->
#
# 	<!-- Google Search Engine Tags / Inicio -->
# 	<meta itemprop="name" content="Laptops | Intel Celeron Empresarial - Memory Kings, lo mejor en equipos de computo y accesorios">
# 	<meta itemprop="description" content="Memory Kings Perú lo mejor en equipos de computo y accesorios, solo las mejores marcas">
# 	<meta itemprop="image" content="">
# 	<!-- Google Search Engine Tags / Fin -->
#
# 	<!-- Open Graph / Inicio -->
# 	<meta property="og:url" content="https://www.memorykings.pe/listados/1028/laptops-intel-celeron-empresarial"/>
# 	<meta property="og:title" content="Laptops | Intel Celeron Empresarial - Memory Kings, lo mejor en equipos de computo y accesorios"/>
# 	<meta property="og:description" content="Memory Kings Perú lo mejor en equipos de computo y accesorios, solo las mejores marcas"/>
# 	<meta property="og:site_name" content="Memory Kings Perú"/>
# 		<meta property="og:image" content=""/>
# 	<meta property="og:type" content="website"/>
# 		<meta property="og:locale" content="es_LA"/>
#
#
# 	<!--
# 	<meta property="product:brand" content="Facebook">
# 	<meta property="product:availability" content="in stock">
# 	<meta property="product:condition" content="new">
# 	<meta property="product:retailer_item_id" content="facebook_tshirt_001">
# 	<meta property="product:item_group_id" content="fb_tshirts">
# 	-->
#
# 	<!-- Open Graph / Fin -->
#
# 	<!-- Twitter Card / Inicio -->
# 	<meta name="twitter:card" content="summary_large_image"/>
# 	<meta name="twitter:site" content="@" />
# 	<meta name="twitter:creator" content="@">
# 	<meta name="twitter:description" content="Memory Kings Perú lo mejor en equipos de computo y accesorios, solo las mejores marcas" />
# 	<meta name="twitter:title" content="Laptops | Intel Celeron Empresarial - Memory Kings, lo mejor en equipos de computo y accesorios" />
# 	<meta name="twitter:image" content=""/>
# 	<!-- Twitter Card / Fin -->
#
# 	<link rel="icon" type="image/png" href="https://cdn.memorykings.pe/v4/images/memory-kings-favicon.png">
# 	<link href="https://fonts.googleapis.com/css?family=Open+Sans&display=swap" rel="stylesheet">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/jquery-ui.css">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/lightslider.css">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/booklet.css">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/main.css?v=1411148379">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/custom.css?v=566269601">
# 	<script src="https://kit.fontawesome.com/33ccb19ba0.js" crossorigin="anonymous"></script>
#
# 	<style type="text/css">
# 	.products>li>div .content .promo.eventos {
# 		background: #0334FF !important;
# 		border: 2px solid #FC2B74 !important;
# 		color: #FFFFFF !important;
# 	}
# 	</style>
#     <!-- Google Tag Manager -->
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-PS8KTMB');</script>
#     <!-- End Google Tag Manager -->
#     </head>
# <body>
# <form action="" method="post" name="memory" id="memory">
#     <input type="hidden" id="proceso" name="proceso" value="">
#
#     <input type="hidden" id="codigo_relacionado" name="codigo_relacionado" value="">
#
#     <input type="hidden" id="recaptcha" name="recaptcha" value="">
#
#     <input type="hidden" id="url_front" name="url_front" value="https://www.memorykings.pe">
#     <input type="hidden" id="url_cdn" name="url_cdn" value="https://cdn.memorykings.pe/v4/">
#     <input type="hidden" id="url_carrito" name="url_carrito" value="https://www.memorykings.pe/carrito-compras">
#     <input type="hidden" id="url_ordenar" name="url_ordenar" value="https://www.memorykings.pe/ordenar-pedido">
#     <input type="hidden" id="url_confirmacion" name="url_confirmacion" value="https://www.memorykings.pe/confirmacion-pedido">
#
#     <input type="hidden" id="url_origen" name="url_origen" value="">
#
#     <input type="hidden" id="total_cargos" name="total_cargos" value="0">
#
#     <input type="hidden" id="codigo_producto" name="codigo_producto" value="0">
#     <input type="hidden" id="nombre_producto" name="nombre_producto" value="">
#     <input type="hidden" id="imagen_producto" name="imagen_producto" value="">
#     <input type="hidden" id="url_producto" name="url_producto" value="https://www.memorykings.pe/listados/1028/laptops-intel-celeron-empresarial">
#
#
#     <input type="hidden" id="es_visitante" name="es_visitante" value="">
#     <input type="hidden" id="codigo_visitante" name="codigo_visitante" value="">
#
#     <input type="hidden" id="codigo_cliente" name="codigo_cliente" value="">
#
#     <input type="hidden" id="numero_orden" name="numero_orden" value="">
#
#     <input type="hidden" id="integracion" name="integracion" value="">
#
#     <header id="myHeader">
#                 <div id="header" class=" container flex flex-between flex-middle gutter-2">
#             <div id="logo"><a href="https://www.memorykings.pe/"><img src="https://cdn.memorykings.pe/v4/images/logo-negative.png" alt="Memory Kings Perú SAC" width="290" height="65"></a></div>
#             <div>
#                 <div id="menu-responsive" toggle-class="active" toggle-slide-element="nav">
#                     <span></span>
#                     <span></span>
#                     <span></span>
#                 </div>
#                                 <div id="header-menu">
#                     <ul>
#                         <li><a href="https://www.memorykings.pe/clientes"><i class="fas fa-chevron-right"></i> Clientes</a></li>
#                         <li><a href="https://www.memorykings.pe/trabaja-nosotros"><i class="fas fa-chevron-right"></i> Trabaja con Nosotros</a></li>
#                         <li><a href="https://www.memorykings.pe/libro-reclamaciones"><i class="fas fa-chevron-right"></i> Libro de Reclamaciones</a></li>
#                         <li><a href="https://www.memorykings.pe/modalidades-pago"><i class="fas fa-chevron-right"></i> Modalidades de Pago</a></li>
#                         <li><a href="https://www.memorykings.pe/politicas-garantia"><i class="fas fa-chevron-right"></i> Políticas de Garantía</a></li>
#                         <li><a href="https://www.memorykings.pe/acerca-memorykings"><i class="fas fa-chevron-right"></i> Nuestra Empresa</a></li>
#                         <li><a href="https://www.memorykings.pe/delivery"><i class="fas fa-chevron-right"></i> Delivery</a></li>
#                     </ul>
#                 </div>
#                 <div class="flex flex-right">
#                     <div class="search-section">
#                         <input class="search" type="search" placeholder="Buscar..." id="buscador_desktop" name="buscador_desktop">
#                         <div class="search-icon"><button type="button" id="bt_buscador_desktop" name="bt_buscador_desktop" aria-label="Buscador Memory Kings"><i class="fas fa-search"></i></button></div>
#                     </div>
#                     <ul class="social-menu flex">
#                                                 <li><a class="facebook" href="https://www.facebook.com/MemorykingsPeru" target="_blank" aria-label="Facebook Memory Kings"><i class="fab fa-facebook-f"></i></a></li>
#                                                                         <li><a class="instagram" href="https://www.instagram.com/memorykings_peru/?hl=es-la" target="_blank" aria-label="Instagram Memory Kings"><i class="fab fa-instagram"></i></a></li>
#                                                                         <li><a class="tiktok" href="https://www.tiktok.com/@memorykings.peru" target="_blank" aria-label="Tiktok Memory Kings"><i class="fab fa-tiktok"></i></a></li>
#                                                                         <li><a class="youtube" href="https://www.youtube.com/MemoryKingsPeru" target="_blank" aria-label="Youtube Memory Kings"><i class="fab fa-youtube"></i></a></li>
#                                                                     </ul>
#                 </div>
#             </div>
#         </div>
#         <nav>
#             <ul class="flex container gutter-1">
#                 <li>
#                     <div class="search-section-responsive">
#                         <input class="search" type="search" placeholder="Buscar..." id="buscador_movil" name="buscador_movil">
#                         <div class="search-icon"><button type="button" id="bt_buscador_movil" name="bt_buscador_movil" aria-label="Buscador Memory Kings"><i class="fas fa-search"></i></button></div>
#                     </div>
#                 </li>
#                                 <li class="dropdown"><a href="https://www.memorykings.pe/productos">Productos <i class="fas fa-chevron-down"></i></a>
#                     <button type="button" aria-label="Desplegar Menu de Categorias"><i class="fas fa-chevron-down"></i><i class="fas fa-chevron-up" style="display: none;"></i></button>
#                     <div>
#                         <
listados/593/monitores-4k-ultra-hd">Monitores 4K ULTRA HD</a></li><li><a href="/listados/486/monitores-compatible-con-playstation-xbox-serie-x">Monitores compatible con | PlayStation | XBOX serie-x </a></li><li><a href="/listados/626/monitores-con-camara-webcam-microfono-parlante">Monitores con Camara | WebCam | Microfono | Parlante</a></li><li><a href="/listados/869/monitores-de-marca-dell-hp-lenovo">Monitores de Marca | Dell | Hp | Lenovo.</a></li><li><a href="/listados/851/monitores-gama-de-colores-adobergb-srgb-dci-p3">Monitores Gama de colores (AdobeRGB),(sRGB),(DCI-P3)</a></li><li><a href="/listados/190/monitores-gama-de-colores-srgb-dci-p3">Monitores Gama de colores (sRGB),(DCI-P3)</a></li><li><a href="/listados/1073/monitores-portatil">Monitores Portatil </a></li><li><a href="/listados/233/monitores-smart-productividad-sin-pc-con-sistema-operativo-tizen-6-5">Monitores SMART (Productividad sin PC, con sistema operativo Tizen 6.5)</a></li><li><a href="/listados/1084/pantallas-de-dibujo-digital-interactiva">Pantallas de dibujo Digital interactiva </a></li><li><a href="/listados/188/pantallas-digital-signage">Pantallas Digital Signage</a></li><li><a href="/listados/580/pantallas-eposter">Pantallas ePoster</a></li><li><a href="/listados/1270/pizarras-interactiva">Pizarras interactiva </a></li><li><a href="/listados/99/soporte-rack-para-monitores">Soporte | Rack para Monitores</a></li><li><a href="/listados/288/soporte-rack-para-televisores">Soporte | Rack para Televisores</a></li></ul>                    </div>
#                 </li>
#                 <li><a href="https://www.memorykings.pe/promociones">Promociones</a></li>
#                                 <li class="dropdown carrito-desplegable">
#                     <a href="#"><i class="fas fa-shopping-cart"></i> Carrito <span class="total-productos">(0)</span></a>
#                 </li>
#                                 <li style="display: none"><a href="#"><i class="fas fa-shopping-cart"></i> Carrito <span>(0)</span></a></li>
#                             </ul>
#         </nav>
#     </header>    <section>
#                 <ul id="slider" class="slider-full">
#             <li class="banner-superior-impresion" data-categoria="SubCategoria - Banner Superior" data-elemento="CHUWI : LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 (029515)">
#             	<a href="https://www.memorykings.pe/filtros/363/chuwi" target="_self" class="banner-superior-click" data-categoria="SubCategoria - Banner Superior" data-elemento="CHUWI : LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 (029515)">
#             		<img src="https://cdn.memorykings.pe/files/2024/03/02/329168-chuwi-2.jpg" alt="029515 - LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11" title="029515 - LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11" />
#             	</a>
#             </li>
#         </ul>
#     </section>
#
#     <section>
#         <div class="breadcrumbs">
#             <div class="container gutter-2 pt-2 pb-2">
#                 <ul class="flex">
#                     <li><a href="https://www.memorykings.pe/">Inicio</a></li>
#                     <li>/</li>
#                     <li><a href="https://www.memorykings.pe/productos">Productos</a></li>
#                     <li>/</li>
#                     <li><a href="/subcategorias/19/laptops">Laptops</a></li>
#                 </ul>
#             </div>
#         </div>
#         <div class="container gutter-2 pt-4">
#             <h1 class="h1">Laptops | Intel Celeron Empresarial</h1>
#         </div>
#
#         <div class="container flex grid-gutter-2 pb-4">
#
#             <div class="col-1-1 col-1-1-m pt-4">
#                 <div class="header-products flex flex-between flex-middle grid-gutter-2">
#                     <div>Mostrando <b>4</b> productos</div>
#                     <div>
#                         <span>Ordenar por </span>
#                         <select id="ordenar_listados">
#                             <option value="0" selected>Seleccione</option>
#                             <option value="1" >Nombre Ascendente</option>
#                             <option value="2" >Nombre Descendente</option>
#                             <option value="3" >Menor a Mayor Precio</option>
#                             <option value="4" >Mayor a Menor Precio</option>
#                             <option value="5" >Oferta Menor a Mayor Precio</option>
#                             <option value="6" >Oferta Mayor a Menor Precio</option>
#                         </select>
#                     </div>
#                 </div>
#                 <div class="gutter-2"><div class="hr pt-3"></div></div>
#                 <ul class="products flex grid-1-4 grid-1-2-m grid-1-1-s pt-2">
#                     <li>
#                         <div>
#                             <a href="/producto/329168/laptop-celeron-j4115-chuwi-gemibook-12-256-13-w11">
#                                 <div class="image">
#                                     <img src="https://cdn.memorykings.pe/files/2023/09/12/329168-MK029515A-1.jpg" alt="LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 ULTRA SLIM">
#                                 </div>
#                                 <div class="content">
#                                     <div class="title">
#                                         <h4>LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 ULTRA SLIM</h4>
#                                     </div>
#                                                                         <div class="price-before">$ 410.00 ó S/ 1,529.00</div>
#                                                                         <div class="price">$ 220.00 ó S/ 820.50</div>
#                                     <div class="stock">Stock: <b>> 10</b></div>
#                                     <div class="code">Código interno: <b>029515</b></div>
#                                                                         <div class="promo oferta">Oferta</div>
#                                                                     </div>
#                             </a>
#                         </div>
#                     </li>
#                     <li>
#                         <div>
#                             <a href="/producto/329169/laptop-celeron-n3450-chuwi-herobook-pro-8-256-13-3">
#                                 <div class="image">
#                                     <img src="https://cdn.memorykings.pe/files/2023/09/12/329169-MK029516A-1.jpg" alt="LAPTOP Celeron N3450 CHUWI Herobook Pro 8|256|13.3 W11 ULTRA SLIM">
#                                 </div>
#                                 <div class="content">
#                                     <div class="title">
#                                         <h4>LAPTOP Celeron N3450 CHUWI Herobook Pro 8|256|13.3 W11 ULTRA SLIM</h4>
#                                     </div>
#                                                                         <div class="price-before">$ 350.00 ó S/ 1,305.50</div>
#                                                                         <div class="price">$ 190.00 ó S/ 708.50</div>
#                                     <div class="stock">Stock: <b>> 10</b></div>
#                                     <div class="code">Código interno: <b>029516</b></div>
#                                                                         <div class="promo oferta">Oferta</div>
#                                                                     </div>
#                             </a>
#                         </div>
#                     </li>
#                     <li>
#                         <div>
#                             <a href="/producto/329950/laptop-celeron-n4020-lenovo-thinkpad-300e">
#                                 <div class="image">
#                                     <img src="https://cdn.memorykings.pe/files/2022/04/20/329950-MK030283A.jpg" alt="LAPTOP Celeron N4020 LENOVO ThinkPad 300E Chromebook 4/32/11.6 Chrome Pantalla Táctil">
#                                 </div>
#                                 <div class="content">
#                                     <div class="title">
#                                         <h4>LAPTOP Celeron N4020 LENOVO ThinkPad 300E Chromebook 4/32/11.6 Chrome Pantalla Táctil</h4>
#                                     </div>
#                                                                         <div class="price">$ 325.00 ó S/ 1,212.00</div>
#                                     <div class="stock">Stock: <b>3</b></div>
#                                     <div class="code">Código interno: <b>030283</b></div>
#                                                                     </div>
#                             </a>
#                         </div>
#                     </li>
#                     <li>
#                         <div>
#                             <a href="/producto/328194/laptop-celeron-n4100-hp-240-g7-4-1tb-14">
#                                 <div class="image">
#                                     <img src="https://cdn.memorykings.pe/files/2023/09/12/328194-MK028540-A.jpg" alt="LAPTOP Celeron N4100 HP 240 G7 4|1TB|14">
#                                 </div>
#                                 <div class="content">
#                                     <div class="title">
#                                         <h4>LAPTOP Celeron N4100 HP 240 G7 4|1TB|14</h4>
#                                     </div>
#                                                                         <div class="price-before">$ 299.00 ó S/ 1,115.00</div>
#                                                                         <div class="price">$ 199.00 ó S/ 742.00</div>
#                                     <div class="stock">Stock: <b>> 10</b></div>
#                                     <div class="code">Código interno: <b>028540</b></div>
#                                                                         <div class="promo oferta">Oferta</div>
#                                                                     </div>
#                             </a>
#                         </div>
#                     </li>
#
#                 </ul>
#
#
#             </div>
#         </div>
#
#     </section>
#
# <section class="gutter-2 pb-4">
#     <div class="breadcrumbs">
#         <ul class="flex gutter-2 pt-2 pb-2">
#             <li class="informativo">Memory Kings - Zona Accesorios para Marcas Propietarias y Salud</li>
#         </ul>
#     </div>
#     <ul  id="carousel-lateral">
#                 <li class="banner-redondeado banner-lateral-impresion" data-categoria="Banner - Lateral" data-elemento="Banner: protecsion-home1">
#             <a href="https://www.memorykings.pe/subcategorias/35/ups-estabilizadores-supresor" class="banner-lateral-click" data-categoria="Banner - Lateral" data-elemento="Banner: protecsion-home1">
#                 <img src="https://cdn.memorykings.pe/files/2020/10/26/protecsion-home1.jpg" alt="protecsion-home1" title="protecsion-home1" />
#             </a>
#         </li>
#                 <li class="banner-redondeado banner-lateral-impresion" data-categoria="Banner - Lateral" data-elemento="Banner: ZONA-OUTLET">
#             <a href="https://www.memorykings.pe/subcategorias/73/zona-outlet-remates" class="banner-lateral-click" data-categoria="Banner - Lateral" data-elemento="Banner: ZONA-OUTLET">
#                 <img src="https://cdn.memorykings.pe/files/2020/10/06/ZONA-OUTLET.jpg" alt="ZONA-OUTLET" title="ZONA-OUTLET" />
#             </a>
#         </li>
#                 <li class="banner-redondeado banner-lateral-impresion" data-categoria="Banner - Lateral" data-elemento="Banner: playstation-lateral">
#             <a href="https://www.memorykings.pe/listados/946/accesorios-para-playstation-3-4" class="banner-lateral-click" data-categoria="Banner - Lateral" data-elemento="Banner: playstation-lateral">
#                 <img src="https://cdn.memorykings.pe/files/2018/11/25/playstation-lateral.jpg" alt="playstation-lateral" title="playstation-lateral" />
#             </a>
#         </li>
#                 <li class="banner-redondeado banner-lateral-impresion" data-categoria="Banner - Lateral" data-elemento="Banner: xbox-lateral">
#             <a href="https://www.memorykings.pe/listados/947/accesorios-para-xbox-one" class="banner-lateral-click" data-categoria="Banner - Lateral" data-elemento="Banner: xbox-lateral">
#                 <img src="https://cdn.memorykings.pe/files/2018/11/21/xbox-lateral.jpg" alt="xbox-lateral" title="xbox-lateral" />
#             </a>
#         </li>
#                 <li class="banner-redondeado banner-lateral-impresion" data-categoria="Banner - Lateral" data-elemento="Banner: accesorios-mac-lateral-1">
#             <a href="https://www.memorykings.pe/subcategorias/54/accesorios-para-mac-ipad-iphone" class="banner-lateral-click" data-categoria="Banner - Lateral" data-elemento="Banner: accesorios-mac-lateral-1">
#                 <img src="https://cdn.memorykings.pe/files/2018/08/28/accesorios-mac-lateral-1.jpg" alt="accesorios-mac-lateral-1" title="accesorios-mac-lateral-1" />
#             </a>
#         </li>
#                 <li class="banner-redondeado banner-lateral-impresion" data-categoria="Banner - Lateral" data-elemento="Banner: super-laptop-lateral">
#             <a href="https://www.memorykings.pe/listados/579/laptops-ci7-ci5-gt-gt-para-gamers-amp-profesionales" class="banner-lateral-click" data-categoria="Banner - Lateral" data-elemento="Banner: super-laptop-lateral">
#                 <img src="https://cdn.memorykings.pe/files/2017/06/04/super-laptop-lateral.jpg" alt="super-laptop-lateral" title="super-laptop-lateral" />
#             </a>
#         </li>
#                 <li class="banner-redondeado banner-lateral-impresion" data-categoria="Banner - Lateral" data-elemento="Banner: suministro-lateral">
#             <a href="https://www.memorykings.pe/subcategorias/39/suministros-tintas-toners-cintas-papel" class="banner-lateral-click" data-categoria="Banner - Lateral" data-elemento="Banner: suministro-lateral">
#                 <img src="https://cdn.memorykings.pe/files/2017/06/04/suministro-lateral.jpg" alt="suministro-lateral" title="suministro-lateral" />
#             </a>
#         </li>
#                 <li class="banner-redondeado banner-lateral-impresion" data-categoria="Banner - Lateral" data-elemento="Banner: accesorios-mac-lateral">
#             <a href="https://www.memorykings.pe/subcategorias/54/accesorios-para-mac-apple" class="banner-lateral-click" data-categoria="Banner - Lateral" data-elemento="Banner: accesorios-mac-lateral">
# ...
#                 </ul>
#             </div>
#
#
#
#         </div>
#     </div>
#     <div class="copy-section pb-3">
#         <div class="container flex flex-between flex-middle gutter-2">
#             <div class="pt-3"><a href="https://www.memorykings.pe/"><img src="https://cdn.memorykings.pe/v4/images/logo-negative-footer.png" alt="Memory Kings logo"></a></div>
#             <div class="white-70 pt-3">© 2013 Memory Kings Perú S.A.C. Todos los derechos reservados.</div>
#         </div>
#     </div>
#
#     <style type="text/css">
#         footer .barra-informativa-cyberwow {
#             box-shadow: 0 -3px 5px rgba(0,0,0,0.2);
#             height: 48px;
#             background-color: #0333FB;
#             color: #FFFFFF;
#             position: fixed;
#             width: 100%;
#             z-index: 99;
#             left: 0;
#             bottom: 48px;
#             padding: 4px 0px;
#         }
#
#         footer .barra-informativa-cyberwow span {
#             font-weight: bold;
#             font-size: 18px;
#         }
#     </style>
#
#     <div class="barra-informativa-cyberwow" style="display: none;">
#         <div class="container flex gutter-2" style="height: 40px;">
#             <div class="col-1-2 flex flex-between flex-middle">¡Aprovecha CYBER WOW en Memory Kings!</div>
#             <div class="col-1-2 flex flex-right flex-middle"><div>Termina en <span id="days"></span> días / <span id="hours"></span> horas / <span id="minutes"></span> minutos / <span id="seconds"></span> segundos</div></div>
#         </div>
#     </div>
#
#     <script type="text/javascript">
#     document.addEventListener('DOMContentLoaded', () => {
#         const DATE_TARGET = new Date('10/30/2023 00:00 AM');
#
#         const SPAN_DAYS = document.querySelector('span#days');
#         const SPAN_HOURS = document.querySelector('span#hours');
#         const SPAN_MINUTES = document.querySelector('span#minutes');
#         const SPAN_SECONDS = document.querySelector('span#seconds');
#
#         const MILLISECONDS_OF_A_SECOND = 1000;
#         const MILLISECONDS_OF_A_MINUTE = MILLISECONDS_OF_A_SECOND * 60;
#         const MILLISECONDS_OF_A_HOUR = MILLISECONDS_OF_A_MINUTE * 60;
#         const MILLISECONDS_OF_A_DAY = MILLISECONDS_OF_A_HOUR * 24
#
#         function updateCountdown() {
#             const NOW = new Date()
#             const DURATION = DATE_TARGET - NOW;
#             const REMAINING_DAYS = Math.floor(DURATION / MILLISECONDS_OF_A_DAY);
#             const REMAINING_HOURS = Math.floor((DURATION % MILLISECONDS_OF_A_DAY) / MILLISECONDS_OF_A_HOUR);
#             const REMAINING_MINUTES = Math.floor((DURATION % MILLISECONDS_OF_A_HOUR) / MILLISECONDS_OF_A_MINUTE);
#             const REMAINING_SECONDS = Math.floor((DURATION % MILLISECONDS_OF_A_MINUTE) / MILLISECONDS_OF_A_SECOND);
#             // Thanks Pablo Monteserín (https://pablomonteserin.com/cuenta-regresiva/)
#
#             SPAN_DAYS.textContent = REMAINING_DAYS;
#             SPAN_HOURS.textContent = REMAINING_HOURS;
#             SPAN_MINUTES.textContent = REMAINING_MINUTES;
#             SPAN_SECONDS.textContent = REMAINING_SECONDS;
#         }
#
#         updateCountdown();
#         setInterval(updateCountdown, MILLISECONDS_OF_A_SECOND);
#     });
#     </script>
#     <div class="barra-informativa">
#         <div class="container flex gutter-2 pt-1 pb-1 info">
#             <div class="container col-1-2 col-1-3-m col-1-1-s flex flex-between flex-middle gutter-2">
#                 <div class="icono_x2">
#                     <a href="https://www.memorykings.pe/asesores-comerciales" class="flex flex-center flex-middle" aria-label="Contácta con tu Asesor de Ventas Online">
#                         <i class="fab fa-whatsapp"></i>
#                         <i class="fab fa-telegram"></i>
#                     </a>
#                 </div>
#                 <div class="content col-x flex-top">
#                     <a href="https://www.memorykings.pe/asesores-comerciales" class="link-blanco" aria-label="Contácta con tu Asesor de Ventas Online">
#                         <h3>Contácta con tu Asesor de Ventas Online</h3>
#                         <p>Haz clic aquí</p>
#                     </a>
#                 </div>
#             </div>
#             <div class="container col-1-4 col-1-3-m col-1-2-s flex flex-between flex-middle gutter-2 separacion">
#                 <div class="icono">
#                     <a href="https://www.memorykings.pe/contactenos" aria-label="Atención al Cliente">
#                         <i class="far fa-envelope"></i>
#                     </a>
#                 </div>
#                 <div class="content col-x flex-top">
#                     <a href="https://www.memorykings.pe/contactenos" class="link-blanco" aria-label="Atención al Cliente">
#                         <h3>Atención al Cliente</h3>
#                         <p>Haz clic aquí</p>
#                     </a>
#                 </div>
#             </div>
#             <div class="container col-1-4 col-1-3-m col-1-2-s flex flex-between flex-middle gutter-2 separacion">
#                 <div class="icono">
#                     <a href="https://www.memorykings.pe/soporte-tecnico" aria-label="Soporte Técnico">
#                         <i class="fas fa-ambulance"></i>
#                     </a>
#                 </div>
#                 <div class="content col-x flex-top">
#                     <a href="https://www.memorykings.pe/soporte-tecnico" class="link-blanco" aria-label="Soporte Técnico">
#                         <h3>Soporte Técnico</h3>
#                         <p>998 245 564</p>
#                     </a>
#                 </div>
#             </div>
#         </div>
#     </div>
#
# </footer>
#
# <button id="button-top" type="button"><i class="fas fa-chevron-up"></i></button>
#
# <div class="overlay" modal-dismiss></div>
# <script src="https://cdn.memorykings.pe/v4/js/jquery-3.4.1.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/jquery-ui.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/datepicker-es.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/main.js?v=1451106195" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/numeral.min.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/RequestObject.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/custom.js?v=1825570686" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/lightslider.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/js.cookie.js" type="text/javascript"></script>
#
# <script>
# $(document).ready(function() {
#
#     $('#slider-headband').lightSlider({
#         auto:true,
#         pauseOnHover: true,
#         adaptiveHeight:true,
#         item:1,
#         slideMargin:0,
#         loop:true,
#         controls: false,
#         pager: false,
#         mode: 'fadeToggle',
#         easing: 'easeInBack',
#         onAfterSlide: function () {
#             categoria = $('#slider-headband').find('.active').attr("data-categoria");
#             elemento = $('#slider-headband').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#slider-headband').find('.active').attr("data-categoria");
#             elemento = $('#slider-headband').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $('#slider').lightSlider({
#         auto:true,
#         pauseOnHover: true,
#         adaptiveHeight:true,
#         item:1,
#         slideMargin:0,
#         loop:true,
#         onAfterSlide: function () {
#             categoria = $('#slider').find('.active').attr("data-categoria");
#             elemento = $('#slider').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#slider').find('.active').attr("data-categoria");
#             elemento = $('#slider').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $('#slider-detalle').lightSlider({
#         auto:true,
#         pauseOnHover: true,
#         adaptiveHeight:true,
#         item:1,
#         controls: false,
#         slideMargin:30,
#         loop:true
#     });
#
#     $('#carousel-lateral').lightSlider({
#         auto:true,
#         pauseOnHover: false,
#         adaptiveHeight:true,
#         item:8,
#         slideMargin:5,
#         loop:true,
#         controls: false,
#         pager: false,
#         autoWidth:false,
#         responsive : [
#             {
#                 breakpoint:800,
#                 settings: {
#                     item:3,
#                     slideMove:1,
#                     slideMargin:6,
#                 }
#             },
#             {
#                 breakpoint:480,
#                 settings: {
#                     item:2,
#                     slideMove:1
#                 }
#             }
#         ],
#         onAfterSlide: function () {
#             categoria = $('#carousel-lateral').find('.active').attr("data-categoria");
#             elemento = $('#carousel-lateral').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#carousel-lateral').find('.active').attr("data-categoria");
#             elemento = $('#carousel-lateral').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $('#carousel-footer').lightSlider({
#         auto:true,
#         pauseOnHover: false,
#         adaptiveHeight:true,
#         item:6,
#         slideMargin:20,
#         loop:true,
#         controls: false,
#         pager: false,
#         autoWidth:false,
#         responsive : [
#             {
#                 breakpoint:800,
#                 settings: {
#                     item:3,
#                     slideMove:1,
#                     slideMargin:6,
#                 }
#             },
#             {
#                 breakpoint:480,
#                 settings: {
#                     item:2,
#                     slideMove:1
#                 }
#             }
#         ],
#         onAfterSlide: function () {
#             categoria = $('#carousel-footer').find('.active').attr("data-categoria");
#             elemento = $('#carousel-footer').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#carousel-footer').find('.active').attr("data-categoria");
#             elemento = $('#carousel-footer').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $('#slider-footer').lightSlider({
#         auto:true,
#         pauseOnHover: true,
#         adaptiveHeight:true,
#         item:1,
#         slideMargin:0,
#         loop:true,
#         controls: false,
#         onAfterSlide: function () {
#             categoria = $('#slider-footer').find('.active').attr("data-categoria");
#             elemento = $('#slider-footer').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#slider-footer').find('.active').attr("data-categoria");
#             elemento = $('#slider-footer').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $("#fecha_nacimiento").datepicker({
#         dateFormat: "dd/mm/yy",
#         changeMonth: true,
#         changeYear: true,
#         yearRange: "-80:-18"
#     });
#
# 	$(".banner-cintillo-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
#     $(".banner-superior-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
# 	$(".banner-medio-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
# 	$(".banner-lateral-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
# 	$(".banner-inferior-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
# 	$(".banner-pie-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
# });
# </script>
#
# <div id="fb-root"></div>
# <script async defer crossorigin="anonymous" src="https://connect.facebook.net/es_ES/sdk.js#xfbml=1&version=v5.0"></script></form>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup
import requests

# solicitud HTTP a la página
url = "https://www.memorykings.pe/listados/1028/laptops-intel-celeron-empresarial"
response = requests.get(url)

# fue exitosa?
if response.status_code == 200:
    # Obtener el HTML de la página
    html_content = response.text
else:
    print("Error al cargar la página:", response.status_code)


# Parsear el HTML
soup = BeautifulSoup(html_content, "html.parser")

# Encontrar todos los elementos de productos
productos = soup.find_all("div", class_="content")

# Iterar sobre los productos y extraer información
for producto in productos:
    # Obtener el nombre del producto
    nombre_producto = producto.find("h4").text.strip()

    # Obtener el precio del producto
    precio = producto.find("div", class_="price").text.strip()

    # print de nombre y precio del producto
    print("Nombre del producto:", nombre_producto)
    print("Precio:", precio)
    print("-" * 30)
# Out:
# Nombre del producto: LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 ULTRA SLIM
# Precio: $ 220.00 ó S/ 820.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron N3450 CHUWI Herobook Pro 8|256|13.3 W11 ULTRA SLIM
# Precio: $ 190.00 ó S/ 708.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron N4020 LENOVO ThinkPad 300E Chromebook 4/32/11.6 Chrome Pantalla Táctil
# Precio: $ 325.00 ó S/ 1,212.00
# ------------------------------
# Nombre del producto: LAPTOP Celeron N4100 HP 240 G7 4|1TB|14
# Precio: $ 199.00 ó S/ 742.00
# ------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-ecdcad95d07e> in <cell line: 23>()
#      23 for producto in productos:
#      24     # Obtener el nombre del producto
# ---> 25     nombre_producto = producto.find("h4").text.strip()
#      26
#      27     # Obtener el precio del producto
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ## AJUSTES PARA CANTIDAD DE VECES A ITERAR **EXITOSO**

# %%
from bs4 import BeautifulSoup
import requests

# solicitud HTTP a la página
url = "https://www.memorykings.pe/listados/1028/laptops-intel-celeron-empresarial"
response = requests.get(url)

# fue ok?
if response.status_code == 200:
    # obtengo html
    html_content = response.text
else:
    print("Error al cargar la página:", response.status_code)

# Parsear
soup = BeautifulSoup(html_content, "html.parser")

# Encouentro la cantidad de productos
num_productos_tag = soup.find("div", class_="header-products").find("b")

# Extraer el número de productos si existe
if num_productos_tag:
    num_productos = int(num_productos_tag.text)
else:
    num_productos = 0

# Encontrar todos los elementos de productos
productos = soup.find_all("div", class_="content")

# Iterar sobre los productos y extraer información
for i in range(num_productos):
    # nombre del producto
    nombre_producto = productos[i].find("h4").text.strip()

    # precio del producto
    precio = productos[i].find("div", class_="price").text.strip()

    # Veo nombre y precio
    print("Nombre del producto:", nombre_producto)
    print("Precio:", precio)
    print("-" * 30)
# Out:
# Nombre del producto: LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 ULTRA SLIM
# Precio: $ 220.00 ó S/ 820.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron N3450 CHUWI Herobook Pro 8|256|13.3 W11 ULTRA SLIM
# Precio: $ 190.00 ó S/ 708.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron N4020 LENOVO ThinkPad 300E Chromebook 4/32/11.6 Chrome Pantalla Táctil
# Precio: $ 325.00 ó S/ 1,212.00
# ------------------------------
# Nombre del producto: LAPTOP Celeron N4100 HP 240 G7 4|1TB|14
# Precio: $ 199.00 ó S/ 742.00
# ------------------------------

# %% [markdown]
# ##PRUEBAS AVANZADAS (acceder a cada subcategoria de laptops) y recuperar la info de cada uan

# %%
from bs4 import BeautifulSoup
import requests
import csv

# obtengo URLs de las subcategorías de laptops
url = "https://www.memorykings.pe/subcategorias/19/laptops"
response = requests.get(url)

if response.status_code == 200:
    #  HTML de la página
    html_content = response.text
    print(html_content)
    soup = BeautifulSoup(html_content, "html.parser")
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#
# 	<title>Laptops - Memory Kings, lo mejor en equipos de computo y accesorios</title>
#
# 	<!-- Google / Inicio -->
# 	<meta name="google-site-verification" content="4x46USn6qIYx_GdXAEAxu-jg9Xyh9wfQzGVQCMo-9d4" />
# 	<meta name="description" content="Memory Kings Perú lo mejor en equipos de computo y accesorios, solo las mejores marcas">
# 	<meta name="keywords" content="Memory Kings, equipos de computo, accesorios de computo, mejores marcas" />
# 	<meta name="news_keywords" content="Memory Kings, equipos de computo, accesorios de computo, mejores marcas"/>
# 	<meta name="language" content="es" />
# 	<meta name="robots" content="index,follow"/>
# 	<meta name="googlebot" content="index, follow" />
# 	<meta name="organization" content="Memory Kings Perú SAC" />
# 	<meta name="revisit-after" content="1 day" />
# 	<meta name="author" content="Memory Kings Perú">
# 	<meta name="copyright" content="© 2013 www.memorykings.com.pe" />
# 	<meta name="origen" content="Memory Kings Perú" />
# 	<meta name="locality" content="Lima, Peru" />
# 	<meta name="distribution" content="global" />
# 		<link rel="image_src" href="" />
# 		<link rel="canonical" href="https://www.memorykings.pe/subcategorias/19/laptops"/>
# 	<!-- Google / Fin -->
#
# 	<!-- Google Search Engine Tags / Inicio -->
# 	<meta itemprop="name" content="Laptops - Memory Kings, lo mejor en equipos de computo y accesorios">
# 	<meta itemprop="description" content="Memory Kings Perú lo mejor en equipos de computo y accesorios, solo las mejores marcas">
# 	<meta itemprop="image" content="">
# 	<!-- Google Search Engine Tags / Fin -->
#
# 	<!-- Open Graph / Inicio -->
# 	<meta property="og:url" content="https://www.memorykings.pe/subcategorias/19/laptops"/>
# 	<meta property="og:title" content="Laptops - Memory Kings, lo mejor en equipos de computo y accesorios"/>
# 	<meta property="og:description" content="Memory Kings Perú lo mejor en equipos de computo y accesorios, solo las mejores marcas"/>
# 	<meta property="og:site_name" content="Memory Kings Perú"/>
# 		<meta property="og:image" content=""/>
# 	<meta property="og:type" content="website"/>
# 		<meta property="og:locale" content="es_LA"/>
#
#
# 	<!--
# 	<meta property="product:brand" content="Facebook">
# 	<meta property="product:availability" content="in stock">
# 	<meta property="product:condition" content="new">
# 	<meta property="product:item_group_id" content="fb_tshirts">
# 	-->
#
# 	<!-- Open Graph / Fin -->
#
# 	<!-- Twitter Card / Inicio -->
# 	<meta name="twitter:card" content="summary_large_image"/>
# 	<meta name="twitter:site" content="@" />
# 	<meta name="twitter:creator" content="@">
# 	<meta name="twitter:description" content="Memory Kings Perú lo mejor en equipos de computo y accesorios, solo las mejores marcas" />
# 	<meta name="twitter:title" content="Laptops - Memory Kings, lo mejor en equipos de computo y accesorios" />
# 	<meta name="twitter:image" content=""/>
# 	<!-- Twitter Card / Fin -->
#
# 	<link rel="icon" type="image/png" href="https://cdn.memorykings.pe/v4/images/memory-kings-favicon.png">
# 	<link href="https://fonts.googleapis.com/css?family=Open+Sans&display=swap" rel="stylesheet">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/jquery-ui.css">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/lightslider.css">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/booklet.css">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/main.css?v=1673245763">
# 	<link rel="stylesheet" href="https://cdn.memorykings.pe/v4/css/custom.css?v=55665052">
# 	<script src="https://kit.fontawesome.com/33ccb19ba0.js" crossorigin="anonymous"></script>
#
# 	<style type="text/css">
# 	.products>li>div .content .promo.eventos {
# 		background: #0334FF !important;
# 		border: 2px solid #FC2B74 !important;
# 		color: #FFFFFF !important;
# 	}
# 	</style>
#     <!-- Google Tag Manager -->
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-PS8KTMB');</script>
#     <!-- End Google Tag Manager -->
#     </head>
# <body>
# <form action="" method="post" name="memory" id="memory">
#     <input type="hidden" id="proceso" name="proceso" value="">
#
#     <input type="hidden" id="codigo_relacionado" name="codigo_relacionado" value="">
#
#     <input type="hidden" id="recaptcha" name="recaptcha" value="">
#
#     <input type="hidden" id="url_front" name="url_front" value="https://www.memorykings.pe">
#     <input type="hidden" id="url_cdn" name="url_cdn" value="https://cdn.memorykings.pe/v4/">
#     <input type="hidden" id="url_carrito" name="url_carrito" value="https://www.memorykings.pe/carrito-compras">
#     <input type="hidden" id="url_ordenar" name="url_ordenar" value="https://www.memorykings.pe/ordenar-pedido">
#     <input type="hidden" id="url_confirmacion" name="url_confirmacion" value="https://www.memorykings.pe/confirmacion-pedido">
#
#     <input type="hidden" id="url_origen" name="url_origen" value="">
#
#     <input type="hidden" id="total_cargos" name="total_cargos" value="0">
#
#     <input type="hidden" id="codigo_producto" name="codigo_producto" value="0">
#     <input type="hidden" id="nombre_producto" name="nombre_producto" value="">
#     <input type="hidden" id="imagen_producto" name="imagen_producto" value="">
#     <input type="hidden" id="url_producto" name="url_producto" value="https://www.memorykings.pe/subcategorias/19/laptops">
#
#
#     <input type="hidden" id="es_visitante" name="es_visitante" value="">
#     <input type="hidden" id="codigo_visitante" name="codigo_visitante" value="">
#
#     <input type="hidden" id="codigo_cliente" name="codigo_cliente" value="">
#
#     <input type="hidden" id="numero_orden" name="numero_orden" value="">
#
#     <input type="hidden" id="integracion" name="integracion" value="">
#
#     <header id="myHeader">
#                 <div id="header" class=" container flex flex-between flex-middle gutter-2">
#             <div id="logo"><a href="https://www.memorykings.pe/"><img src="https://cdn.memorykings.pe/v4/images/logo-negative.png" alt="Memory Kings Perú SAC" width="290" height="65"></a></div>
#             <div>
#                 <div id="menu-responsive" toggle-class="active" toggle-slide-element="nav">
#                     <span></span>
#                     <span></span>
#                     <span></span>
#                 </div>
#                                 <div id="header-menu">
#                     <ul>
#                         <li><a href="https://www.memorykings.pe/clientes"><i class="fas fa-chevron-right"></i> Clientes</a></li>
#                         <li><a href="https://www.memorykings.pe/trabaja-nosotros"><i class="fas fa-chevron-right"></i> Trabaja con Nosotros</a></li>
#                         <li><a href="https://www.memorykings.pe/libro-reclamaciones"><i class="fas fa-chevron-right"></i> Libro de Reclamaciones</a></li>
#                         <li><a href="https://www.memorykings.pe/modalidades-pago"><i class="fas fa-chevron-right"></i> Modalidades de Pago</a></li>
#                         <li><a href="https://www.memorykings.pe/politicas-garantia"><i class="fas fa-chevron-right"></i> Políticas de Garantía</a></li>
#                         <li><a href="https://www.memorykings.pe/acerca-memorykings"><i class="fas fa-chevron-right"></i> Nuestra Empresa</a></li>
#                         <li><a href="https://www.memorykings.pe/delivery"><i class="fas fa-chevron-right"></i> Delivery</a></li>
#                     </ul>
#                 </div>
#                 <div class="flex flex-right">
#                     <div class="search-section">
#                         <input class="search" type="search" placeholder="Buscar..." id="buscador_desktop" name="buscador_desktop">
#                         <div class="search-icon"><button type="button" id="bt_buscador_desktop" name="bt_buscador_desktop" aria-label="Buscador Memory Kings"><i class="fas fa-search"></i></button></div>
#                     </div>
#                     <ul class="social-menu flex">
#                                                 <li><a class="facebook" href="https://www.facebook.com/MemorykingsPeru" target="_blank" aria-label="Facebook Memory Kings"><i class="fab fa-facebook-f"></i></a></li>
#                                                                         <li><a class="instagram" href="https://www.instagram.com/memorykings_peru/?hl=es-la" target="_blank" aria-label="Instagram Memory Kings"><i class="fab fa-instagram"></i></a></li>
#                                                                         <li><a class="tiktok" href="https://www.tiktok.com/@memorykings.peru" target="_blank" aria-label="Tiktok Memory Kings"><i class="fab fa-tiktok"></i></a></li>
#                                                                         <li><a class="youtube" href="https://www.youtube.com/MemoryKingsPeru" target="_blank" aria-label="Youtube Memory Kings"><i class="fab fa-youtube"></i></a></li>
#                                                                     </ul>
#                 </div>
#             </div>
#         </div>
#         <nav>
#             <ul class="flex container gutter-1">
#                 <li>
#                     <div class="search-section-responsive">
#                         <input class="search" type="search" placeholder="Buscar..." id="buscador_movil" name="buscador_movil">
#                         <div class="search-icon"><button type="button" id="bt_buscador_movil" name="bt_buscador_movil" aria-label="Buscador Memory Kings"><i class="fas fa-search"></i></button></div>
#                     </div>
#                 </li>
#                                 <li class="dropdown"><a href="https://www.memorykings.pe/productos">Productos <i class="fas fa-chevron-down"></i></a>
#                     <button type="button" aria-label="Desplegar Menu de Categorias"><i class="fas fa-chevron-down"></i><i class="fas fa-chevron-up" style="display: none;"></i></button>
#                     <div>
#                         <ul><li><a href="/subcategorias/1/accesorios">Accesorios</a></li><li><a href="/subcategorias/37/accesorios-para-laptops">Accesorios para Laptops</a></li><li><a href="/subcategorias/28/adaptadores">Adaptadores</a></li><li><a href="/subcategorias/45/auriculares-microfonos">Auriculares | Microfonos</a></li><li><a href="/subcategorias/38/cables">Cables</a></li><li><a href="/subcategorias/52/camaras-vigilancia-seguridad">Camaras | Vigilancia | Seguridad</a></li><li><a href="/subcategorias/7/camaras-web-foto-video-streaming-drones">Camaras | Web | Foto | Video | Streaming | Drones</a></li><li><a href="/subcategorias/29/case-fuentes">Case | Fuentes</a></li><li><a href="/subcategorias/75/celulares-smartphone-smartwatch">Celulares | smartphone | smartwatch</a></li><li><a href="/subcategorias/72/cooler-enfriadores">Cooler | Enfriadores</a></li><li><a href="/subcategorias/24/discos-duro-almacenamiento-externo">Discos Duro | Almacenamiento | externo</a></li><li><a href="/subcategorias/57/discos-duro-almacenamiento-interno">Discos Duro | Almacenamiento | interno</a></li><li><a href="/
li><li><a href="/listados/851/monitores-gama-de-colores-adobergb-srgb-dci-p3">Monitores Gama de colores (AdobeRGB),(sRGB),(DCI-P3)</a></li><li><a href="/listados/190/monitores-gama-de-colores-srgb-dci-p3">Monitores Gama de colores (sRGB),(DCI-P3)</a></li><li><a href="/listados/1073/monitores-portatil">Monitores Portatil </a></li><li><a href="/listados/233/monitores-smart-productividad-sin-pc-con-sistema-operativo-tizen-6-5">Monitores SMART (Productividad sin PC, con sistema operativo Tizen 6.5)</a></li><li><a href="/listados/1084/pantallas-de-dibujo-digital-interactiva">Pantallas de dibujo Digital interactiva </a></li><li><a href="/listados/188/pantallas-digital-signage">Pantallas Digital Signage</a></li><li><a href="/listados/580/pantallas-eposter">Pantallas ePoster</a></li><li><a href="/listados/1270/pizarras-interactiva">Pizarras interactiva </a></li><li><a href="/listados/99/soporte-rack-para-monitores">Soporte | Rack para Monitores</a></li><li><a href="/listados/288/soporte-rack-para-televisores">Soporte | Rack para Televisores</a></li></ul>                    </div>
#                 </li>
#                 <li><a href="https://www.memorykings.pe/promociones">Promociones</a></li>
#                                 <li class="dropdown carrito-desplegable">
#                     <a href="#"><i class="fas fa-shopping-cart"></i> Carrito <span class="total-productos">(0)</span></a>
#                 </li>
#                                 <li style="display: none"><a href="#"><i class="fas fa-shopping-cart"></i> Carrito <span>(0)</span></a></li>
#                             </ul>
#         </nav>
#     </header>    <section>
#                 <ul id="slider" class="slider-full">
#             <li class="banner-superior-impresion" data-categoria="Categoria - Banner Superior" data-elemento="Samsung Monitores : Combo - LAPTOP Core i7-1165G7 ACER + MONITOR SAMSU (036153)">
#             	<a href="/producto/349308/combo-laptop-core-i7-1165g7-acer-monitor-samsu" target="_self" class="banner-superior-click" data-categoria="Categoria - Banner Superior" data-elemento="Samsung Monitores : Combo - LAPTOP Core i7-1165G7 ACER + MONITOR SAMSU (036153)">
#             		<img src="https://cdn.memorykings.pe/files/2024/03/27/349308-combo_ACER_BANNER.jpg" alt="036153 - Combo - LAPTOP Core i7-1165G7 ACER + MONITOR SAMSU" title="036153 - Combo - LAPTOP Core i7-1165G7 ACER + MONITOR SAMSU" />
#             	</a>
#             </li>
#             <li class="banner-superior-impresion" data-categoria="Categoria - Banner Superior" data-elemento="HP Comercial : LAPTOP Core i3-1005G1 HP 240 G8 8|1TB|14 W11 (030907)">
#             	<a href="https://www.memorykings.pe/filtros/148/hp-comercial" target="_self" class="banner-superior-click" data-categoria="Categoria - Banner Superior" data-elemento="HP Comercial : LAPTOP Core i3-1005G1 HP 240 G8 8|1TB|14 W11 (030907)">
#             		<img src="https://cdn.memorykings.pe/files/2024/03/27/336669-hp_laptops_web.jpg" alt="030907 - LAPTOP Core i3-1005G1 HP 240 G8 8|1TB|14 W11" title="030907 - LAPTOP Core i3-1005G1 HP 240 G8 8|1TB|14 W11" />
#             	</a>
#             </li>
#             <li class="banner-superior-impresion" data-categoria="Categoria - Banner Superior" data-elemento="MSI Laptops : LAPTOP Core i7-13700H MSI Creator M16 B13VE (035014)">
#             	<a href="https://www.memorykings.pe/resultados/creato" target="_self" class="banner-superior-click" data-categoria="Categoria - Banner Superior" data-elemento="MSI Laptops : LAPTOP Core i7-13700H MSI Creator M16 B13VE (035014)">
#             		<img src="https://cdn.memorykings.pe/files/2024/03/27/347635-MSI_web.jpg" alt="035014 - LAPTOP Core i7-13700H MSI Creator M16 B13VE" title="035014 - LAPTOP Core i7-13700H MSI Creator M16 B13VE" />
#             	</a>
#             </li>
#             <li class="banner-superior-impresion" data-categoria="Categoria - Banner Superior" data-elemento="CHUWI : LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 (029515)">
#             	<a href="https://www.memorykings.pe/filtros/363/chuwi" target="_self" class="banner-superior-click" data-categoria="Categoria - Banner Superior" data-elemento="CHUWI : LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 (029515)">
#             		<img src="https://cdn.memorykings.pe/files/2024/03/02/329168-chuwi-2.jpg" alt="029515 - LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11" title="029515 - LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11" />
#             	</a>
#             </li>
#             <li class="banner-superior-impresion" data-categoria="Categoria - Banner Superior" data-elemento="ROG REPUBLIC OF GAMERS by ASUS : LAPTOP Core i7-12700H ASUS ROG Zephyrus M16 (033786)">
#             	<a href="/producto/346412/laptop-core-i7-12700h-asus-rog-zephyrus-m16" target="_self" class="banner-superior-click" data-categoria="Categoria - Banner Superior" data-elemento="ROG REPUBLIC OF GAMERS by ASUS : LAPTOP Core i7-12700H ASUS ROG Zephyrus M16 (033786)">
#             		<img src="https://cdn.memorykings.pe/files/2023/03/11/346412-MK033786GRANDE1.jpg" alt="033786 - LAPTOP Core i7-12700H ASUS ROG Zephyrus M16" title="033786 - LAPTOP Core i7-12700H ASUS ROG Zephyrus M16" />
#             	</a>
#             </li>
#             <li class="banner-superior-impresion" data-categoria="Categoria - Banner Superior" data-elemento="Gigabyte Laptops : LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6 (031253)">
#             	<a href="/producto/337012/laptop-core-i5-11400h-gigabyte-g5-16-512-15-6" target="_self" class="banner-superior-click" data-categoria="Categoria - Banner Superior" data-elemento="Gigabyte Laptops : LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6 (031253)">
#             		<img src="https://cdn.memorykings.pe/files/2022/03/26/337012-MK031253-GRANDE.jpg" alt="031253 - LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" title="031253 - LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" />
#             	</a>
#             </li>
#         </ul>
#     </section>
#
#     <section>
#         <div class="breadcrumbs">
#             <div class="container gutter-2 pt-2 pb-2">
#                 <ul class="flex">
#                     <li><a href="https://www.memorykings.pe/">Inicio</a></li>
#                     <li>/</li>
#                     <li><a href="https://www.memorykings.pe/productos">Productos</a></li>
#                 </ul>
#             </div>
#         </div>
#         <div class="container gutter-2 pt-4">
#             <h1 class="h1">Laptops</h1>
#         </div>
#
#         <div class="container pt-4 pb-4">
#             <div class="header-products flex flex-between flex-middle grid-gutter-2">
#                 <div>Mostrando <b>33</b> subcategorias</div>
#             </div>
#             <ul class="products flex grid-1-4 grid-1-3-m grid-1-2-s grid-1-1-xs pt-2">
#
#                 <li>
#                     <div>
#                         <a href="/listados/284/laptops-intel-celeron">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2022/05/22/laptop-celeron-a.jpg" alt="Laptops | Intel Celeron">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Celeron</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/1028/laptops-intel-celeron-empresarial">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2022/05/24/empresa-laptops-celeron.jpg" alt="Laptops | Intel Celeron Empresarial">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Celeron Empresarial</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/247/laptops-intel-core-i3">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2022/05/22/laptop-ci3-home-a.jpg" alt="Laptops | Intel Core i3">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Core i3</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/466/laptops-intel-core-i3-empresarial">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2022/05/22/laptop-ci3-empresa-a.jpg" alt="Laptops | Intel Core i3 Empresarial">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Core i3 Empresarial</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/258/laptops-intel-core-i5">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2022/05/22/laptop-ci5-home-a.jpg" alt="Laptops | Intel Core i5">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Core i5</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/464/laptops-intel-core-i5-empresarial">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2022/05/22/laptop-ci5-negocios-a.jpg" alt="Laptops | Intel Core i5 Empresarial">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Core i5 Empresarial</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/257/laptops-intel-core-i7">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2022/05/22/Laptop-ci7-home-a1.jpg" alt="Laptops | Intel Core i7">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Core i7</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/465/laptops-intel-core-i7-empresarial">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2022/05/22/laptop-ci7-negocios-a.jpg" alt="Laptops | Intel Core i7 Empresarial">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Core i7 Empresarial</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/927/laptops-intel-core-i9">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2022/03/10/laptop-ci9-homeA.jpg" alt="Laptops | Intel Core i9">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Core i9</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/1263/laptops-intel-core-i9-empresarial">
#                             <div class="image">
#                                 <img src="https://cdn.memorykings.pe/files/2023/09/15/laptops-core-i9-empresarial.jpg" alt="Laptops | Intel Core i9 Empresarial">
#                             </div>
#                             <div class="content">
#                                 <div class="title">
#                                     <h4 class="text-center">Laptops | Intel Core i9 Empresarial</h4>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                 </li>
#
#                 <li>
#                     <div>
#                         <a href="/listados/915/laptops-ryzen-5">
# ...
#                 </ul>
#             </div>
#
#
#
#         </div>
#     </div>
#     <div class="copy-section pb-3">
#         <div class="container flex flex-between flex-middle gutter-2">
#             <div class="pt-3"><a href="https://www.memorykings.pe/"><img src="https://cdn.memorykings.pe/v4/images/logo-negative-footer.png" alt="Memory Kings logo"></a></div>
#             <div class="white-70 pt-3">© 2013 Memory Kings Perú S.A.C. Todos los derechos reservados.</div>
#         </div>
#     </div>
#
#     <style type="text/css">
#         footer .barra-informativa-cyberwow {
#             box-shadow: 0 -3px 5px rgba(0,0,0,0.2);
#             height: 48px;
#             background-color: #0333FB;
#             color: #FFFFFF;
#             position: fixed;
#             width: 100%;
#             z-index: 99;
#             left: 0;
#             bottom: 48px;
#             padding: 4px 0px;
#         }
#
#         footer .barra-informativa-cyberwow span {
#             font-weight: bold;
#             font-size: 18px;
#         }
#     </style>
#
#     <div class="barra-informativa-cyberwow" style="display: none;">
#         <div class="container flex gutter-2" style="height: 40px;">
#             <div class="col-1-2 flex flex-between flex-middle">¡Aprovecha CYBER WOW en Memory Kings!</div>
#             <div class="col-1-2 flex flex-right flex-middle"><div>Termina en <span id="days"></span> días / <span id="hours"></span> horas / <span id="minutes"></span> minutos / <span id="seconds"></span> segundos</div></div>
#         </div>
#     </div>
#
#     <script type="text/javascript">
#     document.addEventListener('DOMContentLoaded', () => {
#         const DATE_TARGET = new Date('10/30/2023 00:00 AM');
#
#         const SPAN_DAYS = document.querySelector('span#days');
#         const SPAN_HOURS = document.querySelector('span#hours');
#         const SPAN_MINUTES = document.querySelector('span#minutes');
#         const SPAN_SECONDS = document.querySelector('span#seconds');
#
#         const MILLISECONDS_OF_A_SECOND = 1000;
#         const MILLISECONDS_OF_A_MINUTE = MILLISECONDS_OF_A_SECOND * 60;
#         const MILLISECONDS_OF_A_HOUR = MILLISECONDS_OF_A_MINUTE * 60;
#         const MILLISECONDS_OF_A_DAY = MILLISECONDS_OF_A_HOUR * 24
#
#         function updateCountdown() {
#             const NOW = new Date()
#             const DURATION = DATE_TARGET - NOW;
#             const REMAINING_DAYS = Math.floor(DURATION / MILLISECONDS_OF_A_DAY);
#             const REMAINING_HOURS = Math.floor((DURATION % MILLISECONDS_OF_A_DAY) / MILLISECONDS_OF_A_HOUR);
#             const REMAINING_MINUTES = Math.floor((DURATION % MILLISECONDS_OF_A_HOUR) / MILLISECONDS_OF_A_MINUTE);
#             const REMAINING_SECONDS = Math.floor((DURATION % MILLISECONDS_OF_A_MINUTE) / MILLISECONDS_OF_A_SECOND);
#             // Thanks Pablo Monteserín (https://pablomonteserin.com/cuenta-regresiva/)
#
#             SPAN_DAYS.textContent = REMAINING_DAYS;
#             SPAN_HOURS.textContent = REMAINING_HOURS;
#             SPAN_MINUTES.textContent = REMAINING_MINUTES;
#             SPAN_SECONDS.textContent = REMAINING_SECONDS;
#         }
#
#         updateCountdown();
#         setInterval(updateCountdown, MILLISECONDS_OF_A_SECOND);
#     });
#     </script>
#     <div class="barra-informativa">
#         <div class="container flex gutter-2 pt-1 pb-1 info">
#             <div class="container col-1-2 col-1-3-m col-1-1-s flex flex-between flex-middle gutter-2">
#                 <div class="icono_x2">
#                     <a href="https://www.memorykings.pe/asesores-comerciales" class="flex flex-center flex-middle" aria-label="Contácta con tu Asesor de Ventas Online">
#                         <i class="fab fa-whatsapp"></i>
#                         <i class="fab fa-telegram"></i>
#                     </a>
#                 </div>
#                 <div class="content col-x flex-top">
#                     <a href="https://www.memorykings.pe/asesores-comerciales" class="link-blanco" aria-label="Contácta con tu Asesor de Ventas Online">
#                         <h3>Contácta con tu Asesor de Ventas Online</h3>
#                         <p>Haz clic aquí</p>
#                     </a>
#                 </div>
#             </div>
#             <div class="container col-1-4 col-1-3-m col-1-2-s flex flex-between flex-middle gutter-2 separacion">
#                 <div class="icono">
#                     <a href="https://www.memorykings.pe/contactenos" aria-label="Atención al Cliente">
#                         <i class="far fa-envelope"></i>
#                     </a>
#                 </div>
#                 <div class="content col-x flex-top">
#                     <a href="https://www.memorykings.pe/contactenos" class="link-blanco" aria-label="Atención al Cliente">
#                         <h3>Atención al Cliente</h3>
#                         <p>Haz clic aquí</p>
#                     </a>
#                 </div>
#             </div>
#             <div class="container col-1-4 col-1-3-m col-1-2-s flex flex-between flex-middle gutter-2 separacion">
#                 <div class="icono">
#                     <a href="https://www.memorykings.pe/soporte-tecnico" aria-label="Soporte Técnico">
#                         <i class="fas fa-ambulance"></i>
#                     </a>
#                 </div>
#                 <div class="content col-x flex-top">
#                     <a href="https://www.memorykings.pe/soporte-tecnico" class="link-blanco" aria-label="Soporte Técnico">
#                         <h3>Soporte Técnico</h3>
#                         <p>998 245 564</p>
#                     </a>
#                 </div>
#             </div>
#         </div>
#     </div>
#
# </footer>
#
# <button id="button-top" type="button"><i class="fas fa-chevron-up"></i></button>
#
# <div class="overlay" modal-dismiss></div>
# <script src="https://cdn.memorykings.pe/v4/js/jquery-3.4.1.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/jquery-ui.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/datepicker-es.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/main.js?v=1126176761" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/numeral.min.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/RequestObject.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/custom.js?v=1718908965" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/lightslider.js" type="text/javascript"></script>
# <script src="https://cdn.memorykings.pe/v4/js/js.cookie.js" type="text/javascript"></script>
#
# <script>
# $(document).ready(function() {
#
#     $('#slider-headband').lightSlider({
#         auto:true,
#         pauseOnHover: true,
#         adaptiveHeight:true,
#         item:1,
#         slideMargin:0,
#         loop:true,
#         controls: false,
#         pager: false,
#         mode: 'fadeToggle',
#         easing: 'easeInBack',
#         onAfterSlide: function () {
#             categoria = $('#slider-headband').find('.active').attr("data-categoria");
#             elemento = $('#slider-headband').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#slider-headband').find('.active').attr("data-categoria");
#             elemento = $('#slider-headband').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $('#slider').lightSlider({
#         auto:true,
#         pauseOnHover: true,
#         adaptiveHeight:true,
#         item:1,
#         slideMargin:0,
#         loop:true,
#         onAfterSlide: function () {
#             categoria = $('#slider').find('.active').attr("data-categoria");
#             elemento = $('#slider').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#slider').find('.active').attr("data-categoria");
#             elemento = $('#slider').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $('#slider-detalle').lightSlider({
#         auto:true,
#         pauseOnHover: true,
#         adaptiveHeight:true,
#         item:1,
#         controls: false,
#         slideMargin:30,
#         loop:true
#     });
#
#     $('#carousel-lateral').lightSlider({
#         auto:true,
#         pauseOnHover: false,
#         adaptiveHeight:true,
#         item:8,
#         slideMargin:5,
#         loop:true,
#         controls: false,
#         pager: false,
#         autoWidth:false,
#         responsive : [
#             {
#                 breakpoint:800,
#                 settings: {
#                     item:3,
#                     slideMove:1,
#                     slideMargin:6,
#                 }
#             },
#             {
#                 breakpoint:480,
#                 settings: {
#                     item:2,
#                     slideMove:1
#                 }
#             }
#         ],
#         onAfterSlide: function () {
#             categoria = $('#carousel-lateral').find('.active').attr("data-categoria");
#             elemento = $('#carousel-lateral').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#carousel-lateral').find('.active').attr("data-categoria");
#             elemento = $('#carousel-lateral').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $('#carousel-footer').lightSlider({
#         auto:true,
#         pauseOnHover: false,
#         adaptiveHeight:true,
#         item:6,
#         slideMargin:20,
#         loop:true,
#         controls: false,
#         pager: false,
#         autoWidth:false,
#         responsive : [
#             {
#                 breakpoint:800,
#                 settings: {
#                     item:3,
#                     slideMove:1,
#                     slideMargin:6,
#                 }
#             },
#             {
#                 breakpoint:480,
#                 settings: {
#                     item:2,
#                     slideMove:1
#                 }
#             }
#         ],
#         onAfterSlide: function () {
#             categoria = $('#carousel-footer').find('.active').attr("data-categoria");
#             elemento = $('#carousel-footer').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#carousel-footer').find('.active').attr("data-categoria");
#             elemento = $('#carousel-footer').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $('#slider-footer').lightSlider({
#         auto:true,
#         pauseOnHover: true,
#         adaptiveHeight:true,
#         item:1,
#         slideMargin:0,
#         loop:true,
#         controls: false,
#         onAfterSlide: function () {
#             categoria = $('#slider-footer').find('.active').attr("data-categoria");
#             elemento = $('#slider-footer').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         },
#         onSliderLoad: function () {
#             categoria = $('#slider-footer').find('.active').attr("data-categoria");
#             elemento = $('#slider-footer').find('.active').attr("data-elemento");
#             valor = 1;
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'Impresion',
#                 'category': categoria,
#                 'label': elemento,
# 			    'value': valor
#             });
#         }
#     });
#
#     $("#fecha_nacimiento").datepicker({
#         dateFormat: "dd/mm/yy",
#         changeMonth: true,
#         changeYear: true,
#         yearRange: "-80:-18"
#     });
#
# 	$(".banner-cintillo-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
#     $(".banner-superior-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
# 	$(".banner-medio-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
# 	$(".banner-lateral-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
# 	$(".banner-inferior-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
#
# 	$(".banner-pie-click").click(function() {
# 		categoria = $(this).attr("data-categoria");
# 		elemento = $(this).attr("data-elemento");
#         valor = 2;
#
# 		window.dataLayer = window.dataLayer || [];
# 		window.dataLayer.push({
# 			'event': 'Click',
# 			'category': categoria,
# 			'label': elemento,
# 			'value': valor
# 		});
# 	});
# });
# </script>
#
# <div id="fb-root"></div>
# <script async defer crossorigin="anonymous" src="https://connect.facebook.net/es_ES/sdk.js#xfbml=1&version=v5.0"></script></form>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup
import requests
import csv

# obtengo URLs de las subcategorías de laptops
url = "https://www.memorykings.pe/subcategorias/19/laptops"
response = requests.get(url)

if response.status_code == 200:
    #  HTML de la página
    html_content = response.text
    soup = BeautifulSoup(html_content, "html.parser")

    # busco los enlaces de subcategorías de laptops
    links = soup.find('ul', class_='products').find_all('a')

    # Crear un archivo CSV y escribir los encabezados
    with open('productos_laptops.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Nombre del producto', 'Precio'])

        # Itero sobre las subcategorías
        for link in links:
            # Construir la URL completa de la subcategoría
            href = link.get('href')
            full_url = "https://www.memorykings.pe" + href

            # obtengo info de los productos de la subcategoría
            subcategoria_response = requests.get(full_url)
            if subcategoria_response.status_code == 200:
                subcategoria_html_content = subcategoria_response.text
                subcategoria_soup = BeautifulSoup(subcategoria_html_content, "html.parser")

                # Busco todos los elementos de productos
                productos = subcategoria_soup.find_all("div", class_="content")

                # busco cantidad de productos
                num_productos_tag = subcategoria_soup.find("div", class_="header-products").find("b")
                if num_productos_tag:
                    num_productos = int(num_productos_tag.text)
                else:
                    num_productos = 0

                # Itero sobre los productos y extraigo info
                for i in range(num_productos):
                    # Nombre del producto
                    nombre_producto = productos[i].find("h4").text.strip()

                    # Precio del producto
                    precio = productos[i].find("div", class_="price").text.strip()

                    # Escribir en el CSV
                    writer.writerow([nombre_producto, precio])

                    print("Nombre del producto:", nombre_producto)
                    print("Precio:", precio)
                    print("-" * 30)
            else:
                print("Error al cargar la página de la subcategoría:", subcategoria_response.status_code)
else:
    print("Error al cargar la página de las subcategorías de laptops:", response.status_code)

print("Los datos se han guardado correctamente en 'productos_laptops.csv'")
# Out:
# Nombre del producto: LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 ULTRA SLIM
# Precio: $ 220.00 ó S/ 825.00
# ------------------------------
# Nombre del producto: LAPTOP Celeron N3450 CHUWI Herobook Pro 8|256|13.3 W11 ULTRA SLIM
# Precio: $ 190.00 ó S/ 712.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron N4100 HP 240 G7 4|1TB|14
# Precio: $ 199.00 ó S/ 746.00
# ------------------------------
# Nombre del producto: LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 ULTRA SLIM
# Precio: $ 220.00 ó S/ 825.00
# ------------------------------
# Nombre del producto: LAPTOP Celeron N3450 CHUWI Herobook Pro 8|256|13.3 W11 ULTRA SLIM
# Precio: $ 190.00 ó S/ 712.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron N4020 LENOVO ThinkPad 300E Chromebook 4/32/11.6 Chrome Pantalla Táctil
# Precio: $ 325.00 ó S/ 1,218.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron N4100 HP 240 G7 4|1TB|14
# Precio: $ 199.00 ó S/ 746.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1005G1 HP 240 G8 8|1TB|14 W11
# Precio: $ 280.00 ó S/ 1,050.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1005G1 HP 240 G8 8|256|14 W11
# Precio: $ 280.00 ó S/ 1,050.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-10110U TOSHIBA TECRA A40 8|256|14"
# Precio: $ 330.00 ó S/ 1,237.50
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1215U LENOVO V15 G3 IAP 8|256|15.6"
# Precio: $ 305.00 ó S/ 1,143.50
# ------------------------------
# Nombre del producto: LAPTOP Core i3-N305 ASUS Vivobook Go 15 E1504GA-NJ191 8|256|15.6"
# Precio: $ 320.00 ó S/ 1,200.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1005G1 HP 240 G8 8|1TB|14 W11
# Precio: $ 280.00 ó S/ 1,050.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1005G1 HP 240 G8 8|256|14 W11
# Precio: $ 280.00 ó S/ 1,050.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-10110U DELL Latitude 3410 4|1TB|14
# Precio: $ 499.00 ó S/ 1,871.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-10110U TOSHIBA TECRA A40 8|256|14"
# Precio: $ 330.00 ó S/ 1,237.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 DELL Inspiron 15 3520 8|512|15.6" W11
# Precio: $ 410.00 ó S/ 1,537.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3060 6GB W11
# Precio: $ 1,499.00 ó S/ 5,621.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,290.00 ó S/ 4,837.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1235U ACER Aspire 3 A315-59G-54FX 8|256|15.6" GEFORCE MX550 2GB
# Precio: $ 660.00 ó S/ 2,475.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1235U ACER Aspire 3 A315-59G-586Q 8|512|15.6" GEFORCE MX550 2GB
# Precio: $ 680.00 ó S/ 2,550.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1240P ASUS Zenbook 14 OLED UX3402ZA-KM233W 8|512|14" W11
# Precio: $ 940.00 ó S/ 3,525.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12450H LENOVO IdeaPad Gaming 3 15IAH7 8|512|15.6" GEFORCE RTX 3050 4GB
# Precio: $ 805.00 ó S/ 3,018.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H ASUS TUF Gaming F15 FX507ZC4-HN005 8|512|15.6" GEFORCE RTX 3050 4GB
# Precio: $ 882.00 ó S/ 3,307.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H GIGABYTE AERO 14 OLED 9MF 16|S1TB|14" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,670.00 ó S/ 6,262.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H GIGABYTE AORUS 15 9KF 8|512|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,480.00 ó S/ 5,550.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1340P LENOVO Yoga Slim 6 14IRP8 16GB|512|14" 2K W11
# Precio: $ 890.00 ó S/ 3,337.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-13450HX DELL Gaming G15 5530 8|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,160.00 ó S/ 4,350.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 LENOVO Thinkpad X1 Carbon G9 16|512|14 W11PRO
# Precio: $ 2,350.00 ó S/ 8,812.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 LENOVO ThinkPad X1 Yoga G6 DUO 16|512|14" W11PRO Pantalla táctil
# Precio: $ 2,499.00 ó S/ 9,371.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1335U DELL Latitude 3540 8|256|15.6 W11PRO
# Precio: $ 875.00 ó S/ 3,281.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1335U HP 250 G10 8|512|15.6"
# Precio: $ 555.00 ó S/ 2,081.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1335U LENOVO Thinkpad E16 G1 16|512|16 W11PRO
# Precio: $ 1,430.00 ó S/ 5,362.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1335U LENOVO Thinkpad L14 G4 16|512|14 W11PRO
# Precio: $ 1,560.00 ó S/ 5,850.00
# ------------------------------
# Nombre del producto: Combo - LAPTOP Core i7-1165G7 ACER + MONITOR SAMSUNG 24" CURVO
# Precio: $ 585.00 ó S/ 2,193.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1165G7 ACER Aspire 5 A514-54-79EW-76 12|512|14"
# Precio: $ 585.00 ó S/ 2,193.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12650H HP VICTUS GAMING 15-fa0007la 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 990.00 ó S/ 3,712.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12650H MSI Thin GF63 12VE 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,145.00 ó S/ 4,293.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H ASUS ROG Zephyrus M16GU603ZE 16/512/16/3050Ti W11
# Precio: $ 1,690.00 ó S/ 6,337.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H ASUS TUF Gaming F15 FX507ZC4-HN002 16|512|15.6" GEFORCE RTX3050 4GB
# Precio: $ 1,145.00 ó S/ 4,293.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 16 XE5 16|S1TB|16" GEFORCE RTX 3070 Ti 8GB W11PRO
# Precio: $ 2,990.00 ó S/ 11,212.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 17 KE5 16|S1TB|17.3" GEFORCE RTX 3060P 6GB W11
# Precio: $ 2,260.00 ó S/ 8,475.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 5 KE4 16|S1TB|15.6" 4K-OLED GEFORCE RTX 3060P 6GB W11
# Precio: $ 1,870.00 ó S/ 7,012.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AORUS 15 XE4 16|S1TB|15.6" 2K GEFORCE RTX 3070 Ti  8GB W11
# Precio: $ 2,399.00 ó S/ 8,996.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AORUS 5 SE4 16|512|15.6" GEFORCE RTX 3070P 8GB W11
# Precio: $ 1,760.00 ó S/ 6,600.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13620H MSI Katana 17 B13VEK 16|512|17.3" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,500.00 ó S/ 5,625.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13650HX DELL Gaming G15 5530 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,620.00 ó S/ 6,075.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AERO 14 OLED BMF 16|S1TB|14" 2.8K GEFORCE RTX 4050 6GB W11
# Precio: $ 2,099.00 ó S/ 7,871.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AORUS 15 BKF 8|512|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,840.00 ó S/ 6,900.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AORUS 15 BKF 16|S1TB|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,899.00 ó S/ 7,121.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Creator M16 B13VE 16|S1TB|16" GEFORCE RTX 4050 6GB W11PRO
# Precio: $ 1,855.00 ó S/ 6,956.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Pulse 15 B13VGK 16|S1TB|15.6" GEFORCE RTX 4070 8GB W11
# Precio: $ 2,290.00 ó S/ 8,587.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Stealth 17 Studio A13VG 16|S1TB/17.3" 2K GEFORCE RTX 4070 8GB W11
# Precio: $ 2,640.00 ó S/ 9,900.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX DELL Alienware M16 R1 16|S1TB|16" GEFORCE RTX 4070 8GB W11
# Precio: $ 3,099.00 ó S/ 11,621.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX MSI Creator Z17 HX Studio A13V 32|S1TB|17" 2K GEFORCE RTX 4070 8GB W11PRO Pantalla Táctil
# Precio: $ 3,155.00 ó S/ 11,831.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 5600H ASUS Vivobook Pro14 OLED 8|512|14 2.8K GEFORCE RTX3050 W11
# Precio: $ 878.00 ó S/ 3,292.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1255U HP 250 G9 8GB|512|15.6"
# Precio: $ 655.00 ó S/ 2,456.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1255U LENOVO V15 G3 IAP 16|512|15
# Precio: $ 650.00 ó S/ 2,437.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1260P LENOVO ThinkPad X1 Yoga G7 DUO 16/512/14" W11PRO Pantalla Táctil
# Precio: $ 2,999.00 ó S/ 11,246.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U ASUS ExpertBook B1 B1502CVA-NJ0791 16|S1TB|15.6"
# Precio: $ 980.00 ó S/ 3,675.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U DELL Latitude 7440 Hybrid DUO 16|512|14" W11PRO Pantalla Táctil
# Precio: $ 1,895.00 ó S/ 7,106.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP 250 G10 8|512|15.6"
# Precio: $ 715.00 ó S/ 2,681.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP Elite Dragonfly G4 DUO 16|S1TB|13.5" W11PRO Pantalla Táctil
# Precio: $ 2,530.00 ó S/ 9,487.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP Elite x360 1040 G10 DUO 16|S1TB|14" W11PRO Pantalla Táctil
# Precio: $ 2,370.00 ó S/ 8,887.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP ProBook 450 16|512|15.6" W11PRO
# Precio: $ 1,245.00 ó S/ 4,668.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H DELL Precision 5680 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 3,360.00 ó S/ 12,600.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VI 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 1,925.00 ó S/ 7,218.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VJ 32|S1TB|16" QUADRO RTX 2000 8GB W11PRO
# Precio: $ 2,330.00 ó S/ 8,737.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VK 32|S2TB|16" QUADRO RTX 3000 8GB W11PRO
# Precio: $ 2,950.00 ó S/ 11,062.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13
50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP Elite Dragonfly G4 DUO 16|S1TB|13.5" W11PRO Pantalla Táctil
# Precio: $ 2,530.00 ó S/ 9,487.50
# ------------------------------
# Nombre del producto: Combo - LAPTOP Core i7-1165G7 ACER + MONITOR SAMSUNG 24" CURVO
# Precio: $ 585.00 ó S/ 2,193.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron N4100 HP 240 G7 4|1TB|14
# Precio: $ 199.00 ó S/ 746.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1005G1 HP 240 G8 8|1TB|14 W11
# Precio: $ 280.00 ó S/ 1,050.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1005G1 HP 240 G8 8|256|14 W11
# Precio: $ 280.00 ó S/ 1,050.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-10110U DELL Latitude 3410 4|1TB|14
# Precio: $ 499.00 ó S/ 1,871.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-10110U TOSHIBA TECRA A40 8|256|14"
# Precio: $ 330.00 ó S/ 1,237.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 LENOVO Thinkpad X1 Carbon G9 16|512|14 W11PRO
# Precio: $ 2,350.00 ó S/ 8,812.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 LENOVO ThinkPad X1 Yoga G6 DUO 16|512|14" W11PRO Pantalla táctil
# Precio: $ 2,499.00 ó S/ 9,371.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1240P ASUS Zenbook 14 OLED UX3402ZA-KM233W 8|512|14" W11
# Precio: $ 940.00 ó S/ 3,525.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H GIGABYTE AERO 14 OLED 9MF 16|S1TB|14" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,670.00 ó S/ 6,262.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1335U LENOVO Thinkpad L14 G4 16|512|14 W11PRO
# Precio: $ 1,560.00 ó S/ 5,850.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1340P LENOVO Yoga Slim 6 14IRP8 16GB|512|14" 2K W11
# Precio: $ 890.00 ó S/ 3,337.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1165G7 ACER Aspire 5 A514-54-79EW-76 12|512|14"
# Precio: $ 585.00 ó S/ 2,193.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1260P LENOVO ThinkPad X1 Yoga G7 DUO 16/512/14" W11PRO Pantalla Táctil
# Precio: $ 2,999.00 ó S/ 11,246.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U DELL Latitude 7440 Hybrid DUO 16|512|14" W11PRO Pantalla Táctil
# Precio: $ 1,895.00 ó S/ 7,106.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP Elite x360 1040 G10 DUO 16|S1TB|14" W11PRO Pantalla Táctil
# Precio: $ 2,370.00 ó S/ 8,887.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AERO 14 OLED BMF 16|S1TB|14" 2.8K GEFORCE RTX 4050 6GB W11
# Precio: $ 2,099.00 ó S/ 7,871.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 4700U LENOVO V14 8|1TB|14"
# Precio: $ 550.00 ó S/ 2,062.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 4700U LENOVO V14 8|256|14"
# Precio: $ 590.00 ó S/ 2,212.50
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1215U LENOVO V15 G3 IAP 8|256|15.6"
# Precio: $ 305.00 ó S/ 1,143.50
# ------------------------------
# Nombre del producto: LAPTOP Core i3-N305 ASUS Vivobook Go 15 E1504GA-NJ191 8|256|15.6"
# Precio: $ 320.00 ó S/ 1,200.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 DELL Inspiron 15 3520 8|512|15.6" W11
# Precio: $ 410.00 ó S/ 1,537.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3060 6GB W11
# Precio: $ 1,499.00 ó S/ 5,621.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,290.00 ó S/ 4,837.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1235U ACER Aspire 3 A315-59G-54FX 8|256|15.6" GEFORCE MX550 2GB
# Precio: $ 660.00 ó S/ 2,475.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-
50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 7840HS DELL Gaming G15 5535 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,475.00 ó S/ 5,531.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1335U LENOVO Thinkpad E16 G1 16|512|16 W11PRO
# Precio: $ 1,430.00 ó S/ 5,362.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H ASUS ROG Zephyrus M16GU603ZE 16/512/16/3050Ti W11
# Precio: $ 1,690.00 ó S/ 6,337.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 16 XE5 16|S1TB|16" GEFORCE RTX 3070 Ti 8GB W11PRO
# Precio: $ 2,990.00 ó S/ 11,212.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Creator M16 B13VE 16|S1TB|16" GEFORCE RTX 4050 6GB W11PRO
# Precio: $ 1,855.00 ó S/ 6,956.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX DELL Alienware M16 R1 16|S1TB|16" GEFORCE RTX 4070 8GB W11
# Precio: $ 3,099.00 ó S/ 11,621.00
# ------------------------------
# Nombre del producto: LAPTOP Core i9-13900H ASUS Vivobook 16 X1605VA-MB195 16GB|S1TB|16"
# Precio: $ 920.00 ó S/ 3,450.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 5800H HP OMEN 16-c0503la 16GB|512|16.1" RADEON RX 6600M 8GB W11
# Precio: $ 1,230.00 ó S/ 4,612.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 7730U ASUS Vivobook 16 16|512|16
# Precio: $ 610.00 ó S/ 2,287.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VI 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 1,925.00 ó S/ 7,218.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VJ 32|S1TB|16" QUADRO RTX 2000 8GB W11PRO
# Precio: $ 2,330.00 ó S/ 8,737.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VK 32|S2TB|16" QUADRO RTX 3000 8GB W11PRO
# Precio: $ 2,950.00 ó S/ 11,062.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700HX HP ZBook Fury G10 32|S2TB/16" QUADRO RTX A2000 8GB W11PRO
# Precio: $ 2,910.00 ó S/ 10,912.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700HX LENOVO ThinkPad P16 G2 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 3,425.00 ó S/ 12,843.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-12900HX LENOVO ThinkPad P16 G1 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 4,140.00 ó S/ 15,525.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z16 HX Studio B13VKTO 64|S2TB|16" QUADRO RTX 3000 8GB W11PRO Pantalla Táctil
# Precio: $ 4,000.00 ó S/ 15,000.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13980HX LENOVO ThinkPad P16 G2 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 4,140.00 ó S/ 15,525.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 17 KE5 16|S1TB|17.3" GEFORCE RTX 3060P 6GB W11
# Precio: $ 2,260.00 ó S/ 8,475.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13620H MSI Katana 17 B13VEK 16|512|17.3" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,500.00 ó S/ 5,625.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Stealth 17 Studio A13VG 16|S1TB/17.3" 2K GEFORCE RTX 4070 8GB W11
# Precio: $ 2,640.00 ó S/ 9,900.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX MSI Creator Z17 HX Studio A13V 32|S1TB|17" 2K GEFORCE RTX 4070 8GB W11PRO Pantalla Táctil
# Precio: $ 3,155.00 ó S/ 11,831.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z17 HX Studio A13VKT 64|S2TB|17" QUADRO RTX 3000 8GB W11PRO Pantalla Tactil
# Precio: $ 4,250.00 ó S/ 15,937.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 5800H HP OMEN 16-c0503la 16GB|512|16.1" RADEON RX 6600M 8GB W11
# Precio: $ 1,230.00 ó S/ 4,612.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3060 6GB W11
# Precio: $ 1,499.00 ó S/ 5,621.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,290.00 ó S/ 4,837.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1235U ACER Aspire 3 A315-59G-54FX 8|256|15.6" GEFORCE MX550 2GB
# Precio: $ 660.00 ó S/ 2,475.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1235U ACER Aspire 3 A315-59G-586Q 8|512|15.6" GEFORCE MX550 2GB
# Precio: $ 680.00 ó S/ 2,550.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12450H LENOVO IdeaPad Gaming 3 15IAH7 8|512|15.6" GEFORCE RTX 3050 4GB
# Precio: $ 805.00 ó S/ 3,018.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H ASUS TUF Gaming F15 FX507ZC4-HN005 8|512|15.6" GEFORCE RTX 3050 4GB
# Precio: $ 882.00 ó S/ 3,307.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H GIGABYTE AERO 14 OLED 9MF 16|S1TB|14" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,670.00 ó S/ 6,262.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H GIGABYTE AORUS 15 9KF 8|512|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,480.00 ó S/ 5,550.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-13450HX DELL Gaming G15 5530 8|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,160.00 ó S/ 4,350.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12650H HP VICTUS GAMING 15-fa0007la 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 990.00 ó S/ 3,712.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12650H MSI Thin GF63 12VE 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,145.00 ó S/ 4,293.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H ASUS ROG Zephyrus M16GU603ZE 16/512/16/3050Ti W11
# Precio: $ 1,690.00 ó S/ 6,337.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H ASUS TUF Gaming F15 FX507ZC4-HN002 16|512|15.6" GEFORCE RTX3050 4GB
# Precio: $ 1,145.00 ó S/ 4,293.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 16 XE5 16|S1TB|16" GEFORCE RTX 3070 Ti 8GB W11PRO
# Precio: $ 2,990.00 ó S/ 11,212.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 17 KE5 16|S1TB|17.3" GEFORCE RTX 3060P 6GB W11
# Precio: $ 2,260.00 ó S/ 8,475.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 5 KE4 16|S1TB|15.6" 4K-OLED GEFORCE RTX 3060P 6GB W11
# Precio: $ 1,870.00 ó S/ 7,012.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AORUS 15 XE4 16|S1TB|15.6" 2K GEFORCE RTX 3070 Ti  8GB W11
# Precio: $ 2,399.00 ó S/ 8,996.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AORUS 5 SE4 16|512|15.6" GEFORCE RTX 3070P 8GB W11
# Precio: $ 1,760.00 ó S/ 6,600.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13620H MSI Katana 17 B13VEK 16|512|17.3" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,500.00 ó S/ 5,625.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13650HX DELL Gaming G15 5530 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,620.00 ó S/ 6,075.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AERO 14 OLED BMF 16|S1TB|14" 2.8K GEFORCE RTX 4050 6GB W11
# Precio: $ 2,099.00 ó S/ 7,871.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AORUS 15 BKF 8|512|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,840.00 ó S/ 6,900.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AORUS 15 BKF 16|S1TB|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,899.00 ó S/ 7,121.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Creator M16 B13VE 16|S1TB|16" GEFORCE RTX 4050 6GB W11PRO
# Precio: $ 1,855.00 ó S/ 6,956.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Pulse 15 B13VGK 16|S1TB|15.6" GEFORCE RTX 4070 8GB W11
# Precio: $ 2,290.00 ó S/ 8,587.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Stealth 17 Studio A13VG 16|S1TB/17.3" 2K GEFORCE RTX 4070 8GB W11
# Precio: $ 2,640.00 ó S/ 9,900.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX DELL Alienware M16 R1 16|S1TB|16" GEFORCE RTX 4070 8GB W11
# Precio: $ 3,099.00 ó S/ 11,621.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX MSI Creator Z17 HX Studio A13V 32|S1TB|17" 2K GEFORCE RTX 4070 8GB W11PRO Pantalla Táctil
# Precio: $ 3,155.00 ó S/ 11,831.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 4600H HP Pavilion 15-ec1037la 16|512|15.6" GEFORCE GTX 1650 Ti 4GB W11
# Precio: $ 815.00 ó S/ 3,056.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 4600H HP Pavilion 15-ec1037la 8|512|15.6" GEFORCE GTX 1650 Ti 4GB W11
# Precio: $ 790.00 ó S/ 2,962.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 5600H DELL Gaming G15 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,145.00 ó S/ 4,293.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 5600H DELL Gaming G15 8|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,120.00 ó S/ 4,200.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 7840HS DELL Gaming G15 5535 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,475.00 ó S/ 5,531.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 9 6900HS ASUS ROG Zephyrus G15 GA503RM-LN118W 16|512|15.6" 2K GEFORCE RTX 3060 6GB W11
# Precio: $ 2,220.00 ó S/ 8,325.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H DELL Precision 5680 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 3,360.00 ó S/ 12,600.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VI 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 1,925.00 ó S/ 7,218.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VJ 32|S1TB|16" QUADRO RTX 2000 8GB W11PRO
# Precio: $ 2,330.00 ó S/ 8,737.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VK 32|S2TB|16" QUADRO RTX 3000 8GB W11PRO
# Precio: $ 2,950.00 ó S/ 11,062.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700HX HP ZBook Fury G10 32|S2TB/16" QUADRO RTX A2000 8GB W11PRO
# Precio: $ 2,910.00 ó S/ 10,912.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700HX LENOVO ThinkPad P16 G2 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 3,425.00 ó S/ 12,843.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-12900HX LENOVO ThinkPad P16 G1 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 4,140.00 ó S/ 15,525.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z16 HX Studio B13VKTO 64|S2TB|16" QUADRO RTX 3000 8GB W11PRO Pantalla Táctil
# Precio: $ 4,000.00 ó S/ 15,000.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z17 HX Studio A13VKT 64|S2TB|17" QUADRO RTX 3000 8GB W11PRO Pantalla Tactil
# Precio: $ 4,250.00 ó S/ 15,937.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13980HX LENOVO ThinkPad P16 G2 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 4,140.00 ó S/ 15,525.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX MSI Creator Z17 HX Studio A13V 32|S1TB|17" 2K GEFORCE RTX 4070 8GB W11PRO Pantalla Táctil
# Precio: $ 3,155.00 ó S/ 11,831.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z16 HX Studio B13VKTO 64|S2TB|16" QUADRO RTX 3000 8GB W11PRO Pantalla Táctil
# Precio: $ 4,000.00 ó S/ 15,000.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z17 HX Studio A13VKT 64|S2TB|17" QUADRO RTX 3000 8GB W11PRO Pantalla Tactil
# Precio: $ 4,250.00 ó S/ 15,937.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron N4020 LENOVO ThinkPad 300E Chromebook 4/32/11.6 Chrome Pantalla Táctil
# Precio: $ 325.00 ó S/ 1,218.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 LENOVO ThinkPad X1 Yoga G6 DUO 16|512|14" W11PRO Pantalla táctil
# Precio: $ 2,499.00 ó S/ 9,371.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1260P LENOVO ThinkPad X1 Yoga G7 DUO 16/512/14" W11PRO Pantalla Táctil
# Precio: $ 2,999.00 ó S/ 11,246.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U DELL Latitude 7440 Hybrid DUO 16|512|14" W11PRO Pantalla Táctil
# Precio: $ 1,895.00 ó S/ 7,106.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP Elite Dragonfly G4 DUO 16|S1TB|13.5" W11PRO Pantalla Táctil
# Precio: $ 2,530.00 ó S/ 9,487.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP Elite x360 1040 G10 DUO 16|S1TB|14" W11PRO Pantalla Táctil
# Precio: $ 2,370.00 ó S/ 8,887.50
# ------------------------------
# Nombre del producto: LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 W11 ULTRA SLIM
# Precio: $ 220.00 ó S/ 825.00
# ------------------------------
# Nombre del producto: LAPTOP Celeron N3450 CHUWI Herobook Pro 8|256|13.3 W11 ULTRA SLIM
# Precio: $ 190.00 ó S/ 712.50
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1005G1 HP 240 G8 8|1TB|14 W11
# Precio: $ 280.00 ó S/ 1,050.00
# ------------------------------
# Nombre del producto: LAPTOP Core i3-1005G1 HP 240 G8 8|256|14 W11
# Precio: $ 280.00 ó S/ 1,050.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 DELL Inspiron 15 3520 8|512|15.6" W11
# Precio: $ 410.00 ó S/ 1,537.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,290.00 ó S/ 4,837.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3060 6GB W11
# Precio: $ 1,499.00 ó S/ 5,621.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1240P ASUS Zenbook 14 OLED UX3402ZA-KM233W 8|512|14" W11
# Precio: $ 940.00 ó S/ 3,525.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H GIGABYTE AERO 14 OLED 9MF 16|S1TB|14" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,670.00 ó S/ 6,262.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H GIGABYTE AORUS 15 9KF 8|512|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,480.00 ó S/ 5,550.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1340P LENOVO Yoga Slim 6 14IRP8 16GB|512|14" 2K W11
# Precio: $ 890.00 ó S/ 3,337.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-13450HX DELL Gaming G15 5530 8|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,160.00 ó S/ 4,350.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12650H HP VICTUS GAMING 15-fa0007la 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 990.00 ó S/ 3,712.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12650H MSI Thin GF63 12VE 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,145.00 ó S/ 4,293.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H ASUS ROG Zephyrus M16GU603ZE 16/512/16/3050Ti W11
# Precio: $ 1,690.00 ó S/ 6,337.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 17 KE5 16|S1TB|17.3" GEFORCE RTX 3060P 6GB W11
# Precio: $ 2,260.00 ó S/ 8,475.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 5 KE4 16|S1TB|15.6" 4K-OLED GEFORCE RTX 3060P 6GB W11
# Precio: $ 1,870.00 ó S/ 7,012.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AORUS 15 XE4 16|S1TB|15.6" 2K GEFORCE RTX 3070 Ti  8GB W11
# Precio: $ 2,399.00 ó S/ 8,996.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AORUS 5 SE4 16|512|15.6" GEFORCE RTX 3070P 8GB W11
# Precio: $ 1,760.00 ó S/ 6,600.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13620H MSI Katana 17 B13VEK 16|512|17.3" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,500.00 ó S/ 5,625.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13650HX DELL Gaming G15 5530 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,620.00 ó S/ 6,075.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AERO 14 OLED BMF 16|S1TB|14" 2.8K GEFORCE RTX 4050 6GB W11
# Precio: $ 2,099.00 ó S/ 7,871.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AORUS 15 BKF 8|512|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,840.00 ó S/ 6,900.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AORUS 15 BKF 16|S1TB|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,899.00 ó S/ 7,121.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Pulse 15 B13VGK 16|S1TB|15.6" GEFORCE RTX 4070 8GB W11
# Precio: $ 2,290.00 ó S/ 8,587.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Stealth 17 Studio A13VG 16|S1TB/17.3" 2K GEFORCE RTX 4070 8GB W11
# Precio: $ 2,640.00 ó S/ 9,900.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX DELL Alienware M16 R1 16|S1TB|16" GEFORCE RTX 4070 8GB W11
# Precio: $ 3,099.00 ó S/ 11,621.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 4600H HP Pavilion 15-ec1037la 8|512|15.6" GEFORCE GTX 1650 Ti 4GB W11
# Precio: $ 790.00 ó S/ 2,962.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 4600H HP Pavilion 15-ec1037la 16|512|15.6" GEFORCE GTX 1650 Ti 4GB W11
# Precio: $ 815.00 ó S/ 3,056.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 5500U HP 15-ef2511la 8|256|15.6 W11
# Precio: $ 485.00 ó S/ 1,818.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 5600H DELL Gaming G15 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,145.00 ó S/ 4,293.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 5600H DELL Gaming G15 8|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,120.00 ó S/ 4,200.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 5800H HP OMEN 16-c0503la 16GB|512|16.1" RADEON RX 6600M 8GB W11
# Precio: $ 1,230.00 ó S/ 4,612.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 7840HS DELL Gaming G15 5535 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,475.00 ó S/ 5,531.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 9 6900HS ASUS ROG Zephyrus G15 GA503RM-LN118W 16|512|15.6" 2K GEFORCE RTX 3060 6GB W11
# Precio: $ 2,220.00 ó S/ 8,325.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 LENOVO Thinkpad X1 Carbon G9 16|512|14 W11PRO
# Precio: $ 2,350.00 ó S/ 8,812.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1135G7 LENOVO ThinkPad X1 Yoga G6 DUO 16|512|14" W11PRO Pantalla táctil
# Precio: $ 2,499.00 ó S/ 9,371.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1335U DELL Latitude 3540 8|256|15.6 W11PRO
# Precio: $ 875.00 ó S/ 3,281.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1335U LENOVO Thinkpad E16 G1 16|512|16 W11PRO
# Precio: $ 1,430.00 ó S/ 5,362.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-1335U LENOVO Thinkpad L14 G4 16|512|14 W11PRO
# Precio: $ 1,560.00 ó S/ 5,850.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1260P LENOVO ThinkPad X1 Yoga G7 DUO 16/512/14" W11PRO Pantalla Táctil
# Precio: $ 2,999.00 ó S/ 11,246.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 16 XE5 16|S1TB|16" GEFORCE RTX 3070 Ti 8GB W11PRO
# Precio: $ 2,990.00 ó S/ 11,212.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U DELL Latitude 7440 Hybrid DUO 16|512|14" W11PRO Pantalla Táctil
# Precio: $ 1,895.00 ó S/ 7,106.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP Elite Dragonfly G4 DUO 16|S1TB|13.5" W11PRO Pantalla Táctil
# Precio: $ 2,530.00 ó S/ 9,487.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP Elite x360 1040 G10 DUO 16|S1TB|14" W11PRO Pantalla Táctil
# Precio: $ 2,370.00 ó S/ 8,887.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-1355U HP ProBook 450 16|512|15.6" W11PRO
# Precio: $ 1,245.00 ó S/ 4,668.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Creator M16 B13VE 16|S1TB|16" GEFORCE RTX 4050 6GB W11PRO
# Precio: $ 1,855.00 ó S/ 6,956.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX MSI Creator Z17 HX Studio A13V 32|S1TB|17" 2K GEFORCE RTX 4070 8GB W11PRO Pantalla Táctil
# Precio: $ 3,155.00 ó S/ 11,831.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H DELL Precision 5680 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 3,360.00 ó S/ 12,600.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VI 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 1,925.00 ó S/ 7,218.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VJ 32|S1TB|16" QUADRO RTX 2000 8GB W11PRO
# Precio: $ 2,330.00 ó S/ 8,737.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VK 32|S2TB|16" QUADRO RTX 3000 8GB W11PRO
# Precio: $ 2,950.00 ó S/ 11,062.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700HX HP ZBook Fury G10 32|S2TB/16" QUADRO RTX A2000 8GB W11PRO
# Precio: $ 2,910.00 ó S/ 10,912.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700HX LENOVO ThinkPad P16 G2 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 3,425.00 ó S/ 12,843.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-12900HX LENOVO ThinkPad P16 G1 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 4,140.00 ó S/ 15,525.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z16 HX Studio B13VKTO 64|S2TB|16" QUADRO RTX 3000 8GB W11PRO Pantalla Táctil
# Precio: $ 4,000.00 ó S/ 15,000.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z17 HX Studio A13VKT 64|S2TB|17" QUADRO RTX 3000 8GB W11PRO Pantalla Tactil
# Precio: $ 4,250.00 ó S/ 15,937.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13980HX LENOVO ThinkPad P16 G2 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 4,140.00 ó S/ 15,525.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Pulse 15 B13VGK 16|S1TB|15.6" GEFORCE RTX 4070 8GB W11
# Precio: $ 2,290.00 ó S/ 8,587.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 4600H HP Pavilion 15-ec1037la 16|512|15.6" GEFORCE GTX 1650 Ti 4GB W11
# Precio: $ 815.00 ó S/ 3,056.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 4600H HP Pavilion 15-ec1037la 8|512|15.6" GEFORCE GTX 1650 Ti 4GB W11
# Precio: $ 790.00 ó S/ 2,962.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 5600H DELL Gaming G15 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,145.00 ó S/ 4,293.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 5 5600H DELL Gaming G15 8|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,120.00 ó S/ 4,200.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 5800H HP OMEN 16-c0503la 16GB|512|16.1" RADEON RX 6600M 8GB W11
# Precio: $ 1,230.00 ó S/ 4,612.50
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 7 7840HS DELL Gaming G15 5535 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,475.00 ó S/ 5,531.00
# ------------------------------
# Nombre del producto: LAPTOP Ryzen 9 6900HS ASUS ROG Zephyrus G15 GA503RM-LN118W 16|512|15.6" 2K GEFORCE RTX 3060 6GB W11
# Precio: $ 2,220.00 ó S/ 8,325.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,290.00 ó S/ 4,837.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-11400H GIGABYTE G5 16|512|15.6" GEFORCE RTX 3060 6GB W11
# Precio: $ 1,499.00 ó S/ 5,621.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12450H LENOVO IdeaPad Gaming 3 15IAH7 8|512|15.6" GEFORCE RTX 3050 4GB
# Precio: $ 805.00 ó S/ 3,018.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H ASUS TUF Gaming F15 FX507ZC4-HN005 8|512|15.6" GEFORCE RTX 3050 4GB
# Precio: $ 882.00 ó S/ 3,307.50
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H GIGABYTE AORUS 15 9KF 8|512|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,480.00 ó S/ 5,550.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-13450HX DELL Gaming G15 5530 8|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 1,160.00 ó S/ 4,350.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12650H HP VICTUS GAMING 15-fa0007la 16|512|15.6" GEFORCE RTX 3050 4GB W11
# Precio: $ 990.00 ó S/ 3,712.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H ASUS ROG Zephyrus M16GU603ZE 16/512/16/3050Ti W11
# Precio: $ 1,690.00 ó S/ 6,337.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H ASUS TUF Gaming F15 FX507ZC4-HN002 16|512|15.6" GEFORCE RTX3050 4GB
# Precio: $ 1,145.00 ó S/ 4,293.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 16 XE5 16|S1TB|16" GEFORCE RTX 3070 Ti 8GB W11PRO
# Precio: $ 2,990.00 ó S/ 11,212.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 17 KE5 16|S1TB|17.3" GEFORCE RTX 3060P 6GB W11
# Precio: $ 2,260.00 ó S/ 8,475.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 5 KE4 16|S1TB|15.6" 4K-OLED GEFORCE RTX 3060P 6GB W11
# Precio: $ 1,870.00 ó S/ 7,012.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AORUS 15 XE4 16|S1TB|15.6" 2K GEFORCE RTX 3070 Ti  8GB W11
# Precio: $ 2,399.00 ó S/ 8,996.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AORUS 5 SE4 16|512|15.6" GEFORCE RTX 3070P 8GB W11
# Precio: $ 1,760.00 ó S/ 6,600.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13620H MSI Katana 17 B13VEK 16|512|17.3" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,500.00 ó S/ 5,625.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13650HX DELL Gaming G15 5530 16|512|15.6" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,620.00 ó S/ 6,075.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AORUS 15 BKF 16|S1TB|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,899.00 ó S/ 7,121.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AORUS 15 BKF 8|512|15.6" GEFORCE RTX 4060 8GB W11
# Precio: $ 1,840.00 ó S/ 6,900.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Pulse 15 B13VGK 16|S1TB|15.6" GEFORCE RTX 4070 8GB W11
# Precio: $ 2,290.00 ó S/ 8,587.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Stealth 17 Studio A13VG 16|S1TB/17.3" 2K GEFORCE RTX 4070 8GB W11
# Precio: $ 2,640.00 ó S/ 9,900.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX DELL Alienware M16 R1 16|S1TB|16" GEFORCE RTX 4070 8GB W11
# Precio: $ 3,099.00 ó S/ 11,621.00
# ------------------------------
# Nombre del producto: LAPTOP Core i5-12500H GIGABYTE AERO 14 OLED 9MF 16|S1TB|14" GEFORCE RTX 4050 6GB W11
# Precio: $ 1,670.00 ó S/ 6,262.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 16 XE5 16|S1TB|16" GEFORCE RTX 3070 Ti 8GB W11PRO
# Precio: $ 2,990.00 ó S/ 11,212.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 17 KE5 16|S1TB|17.3" GEFORCE RTX 3060P 6GB W11
# Precio: $ 2,260.00 ó S/ 8,475.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-12700H GIGABYTE AERO 5 KE4 16|S1TB|15.6" 4K-OLED GEFORCE RTX 3060P 6GB W11
# Precio: $ 1,870.00 ó S/ 7,012.50
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H GIGABYTE AERO 14 OLED BMF 16|S1TB|14" 2.8K GEFORCE RTX 4050 6GB W11
# Precio: $ 2,099.00 ó S/ 7,871.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700H MSI Creator M16 B13VE 16|S1TB|16" GEFORCE RTX 4050 6GB W11PRO
# Precio: $ 1,855.00 ó S/ 6,956.00
# ------------------------------
# Nombre del producto: LAPTOP Core i7-13700HX MSI Creator Z17 HX Studio A13V 32|S1TB|17" 2K GEFORCE RTX 4070 8GB W11PRO Pantalla Táctil
# Precio: $ 3,155.00 ó S/ 11,831.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VI 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 1,925.00 ó S/ 7,218.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VJ 32|S1TB|16" QUADRO RTX 2000 8GB W11PRO
# Precio: $ 2,330.00 ó S/ 8,737.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VK 32|S2TB|16" QUADRO RTX 3000 8GB W11PRO
# Precio: $ 2,950.00 ó S/ 11,062.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z16 HX Studio B13VKTO 64|S2TB|16" QUADRO RTX 3000 8GB W11PRO Pantalla Táctil
# Precio: $ 4,000.00 ó S/ 15,000.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z17 HX Studio A13VKT 64|S2TB|17" QUADRO RTX 3000 8GB W11PRO Pantalla Tactil
# Precio: $ 4,250.00 ó S/ 15,937.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H DELL Precision 5680 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 3,360.00 ó S/ 12,600.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VI 16|S1TB|16" QUADRO RTX A1000 6GB W11PRO
# Precio: $ 1,925.00 ó S/ 7,218.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VJ 32|S1TB|16" QUADRO RTX 2000 8GB W11PRO
# Precio: $ 2,330.00 ó S/ 8,737.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700H MSI CreatorPro M16 B13VK 32|S2TB|16" QUADRO RTX 3000 8GB W11PRO
# Precio: $ 2,950.00 ó S/ 11,062.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700HX HP ZBook Fury G10 32|S2TB/16" QUADRO RTX A2000 8GB W11PRO
# Precio: $ 2,910.00 ó S/ 10,912.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i7-13700HX LENOVO ThinkPad P16 G2 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 3,425.00 ó S/ 12,843.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-12900HX LENOVO ThinkPad P16 G1 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 4,140.00 ó S/ 15,525.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z16 HX Studio B13VKTO 64|S2TB|16" QUADRO RTX 3000 8GB W11PRO Pantalla Táctil
# Precio: $ 4,000.00 ó S/ 15,000.00
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13950HX MSI CreatorPro Z17 HX Studio A13VKT 64|S2TB|17" QUADRO RTX 3000 8GB W11PRO Pantalla Tactil
# Precio: $ 4,250.00 ó S/ 15,937.50
# ------------------------------
# Nombre del producto: LAPTOP WS Core i9-13980HX LENOVO ThinkPad P16 G2 32|S1TB|16" NVIDIA RTX A2000 8GB
# Precio: $ 4,140.00 ó S/ 15,525.00
# ------------------------------
# Nombre del producto: MONITOR portatil 14 HP E14 G4 IPS FHD
# Precio: $ 240.00 ó S/ 900.00
# ------------------------------
# Nombre del producto: MONITOR portatil 15.6 VIEWSONIC TD1655 FHD Tactil
# Precio: $ 360.00 ó S/ 1,350.00
# ------------------------------
# Los datos se han guardado correctamente en 'productos_laptops.csv'

# %%
import pandas as pd
df=pd.read_csv('productos_laptops.csv')
df
# Out:
#                                    Nombre del producto  \
# 0    LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 ...
# 1    LAPTOP Celeron N3450 CHUWI Herobook Pro 8|256|...
# 2              LAPTOP Celeron N4100 HP 240 G7 4|1TB|14
# 3    LAPTOP Celeron J4115 CHUWI Gemibook 12|256|13 ...
# 4    LAPTOP Celeron N3450 CHUWI Herobook Pro 8|256|...
# ..                                                 ...
# 330  LAPTOP WS Core i9-13950HX MSI CreatorPro Z16 H...
# 331  LAPTOP WS Core i9-13950HX MSI CreatorPro Z17 H...
# 332  LAPTOP WS Core i9-13980HX LENOVO ThinkPad P16 ...
# 333              MONITOR portatil 14 HP E14 G4 IPS FHD
# 334  MONITOR portatil 15.6 VIEWSONIC TD1655 FHD Tactil
#
#                         Precio
# 0         $ 220.00 ó S/ 825.00
# 1         $ 190.00 ó S/ 712.50
# 2         $ 199.00 ó S/ 746.00
# 3         $ 220.00 ó S/ 825.00
# 4         $ 190.00 ó S/ 712.50
# ..                         ...
# 330  $ 4,000.00 ó S/ 15,000.00
# 331  $ 4,250.00 ó S/ 15,937.50
# 332  $ 4,140.00 ó S/ 15,525.00
# 333       $ 240.00 ó S/ 900.00
# 334     $ 360.00 ó S/ 1,350.00
#
# [335 rows x 2 columns]
